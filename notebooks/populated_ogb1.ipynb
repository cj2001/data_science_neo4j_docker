# %%
import time
import pandas as pd
import numpy as np
from neo4j import GraphDatabase

# %%
from ogb.lsc import WikiKG90MDataset
dataset = WikiKG90MDataset(root = './data')

# %%
print(dataset.num_entities) # number of entities
print(dataset.num_relations) # number of relation types
print(dataset.num_feat_dims) # dimensionality of entity/relation features.
# Out:
# 87143637
# 1315
# 768

# %%
train_hrt = dataset.train_hrt # numpy ndarray of shape (num_triplets, 3)
print(train_hrt[0:10]) # get i-th training triplet [h, r, t]
# Out:
# [[      0    1182  650146]
#  [      0    1182  650332]
#  [      0     876  989978]
#  [      0     168 1054521]
#  [      0    1182 1632931]
#  [      0     876 2437486]
#  [      0     324 2705654]
#  [      0     324 5885915]
#  [      0     427 6972024]
#  [      0     427 7156732]]

# %%
train_df = pd.DataFrame(train_hrt, columns = ['source', 'edge', 'target'])
train_df.head()
# Out:
#    source  edge   target
# 0       0  1182   650146
# 1       0  1182   650332
# 2       0   876   989978
# 3       0   168  1054521
# 4       0  1182  1632931

# %%
class Neo4jConnection:
    
    def __init__(self, uri, user, pwd):
        self.__uri = uri
        self.__user = user
        self.__pwd = pwd
        self.__driver = None
        try:
            self.__driver = GraphDatabase.driver(self.__uri, auth=(self.__user, self.__pwd))
        except Exception as e:
            print("Failed to create the driver:", e)
        
    def close(self):
        if self.__driver is not None:
            self.__driver.close()
        
    def query(self, query, parameters=None, db=None):
        assert self.__driver is not None, "Driver not initialized!"
        session = None
        response = None
        try: 
            session = self.__driver.session(database=db) if db is not None else self.__driver.session() 
            response = list(session.run(query, parameters))
        except Exception as e:
            print("Query failed:", e)
        finally: 
            if session is not None:
                session.close()
        return response

# %%
conn = Neo4jConnection(uri='bolt://neo4j:7687', user='neo4j', pwd='1234')
conn.query('CREATE CONSTRAINT nodes IF NOT EXISTS ON (n:Node) ASSERT n.id IS UNIQUE')
# Out:
# []

# %%
src = pd.DataFrame(train_df[['source']]).drop_duplicates(subset=['source']).rename(columns={'source': 'node_id'})
tar = pd.DataFrame(train_df[['target']]).drop_duplicates(subset=['target']).rename(columns={'target': 'node_id'})
node_df = pd.concat([src, tar])
node_df.head()
# Out:
#      node_id
# 0          0
# 36         1
# 135        2
# 269        3
# 278        4

# %%
node_df_dedup = node_df.drop_duplicates(subset=['node_id'])
node_df_dedup.head()
# Out:
#      node_id
# 0          0
# 36         1
# 135        2
# 269        3
# 278        4

# %%
node_df_dedup.shape, node_df_dedup.dtypes
# Out:
# ((87143637, 1),
#  node_id    int64
#  dtype: object)

# %%
def add_nodes(rows, batch_size=100000):
    
    query = '''UNWIND $rows AS row
               MERGE (:Node {id: row.node_id})
               RETURN COUNT(*) AS total
    '''
    
    return insert_data(query, rows, batch_size)


def add_edges(rows, batch_size=50000):
    
    
    query = """UNWIND $rows AS row
               MATCH (src:Node {id: row.source}), (tar:Node {id: row.target})
               CREATE (src)-[:REL_%s]->(tar)
    """ % edge
    
    return insert_data(query, rows, batch_size)


def get_embs(val):

    return dataset.entity_feat[val].tolist()


def add_embeddings(rows, batch_size=10000):
    
    query = """CALL apoc.periodic.iterate(
                   'UNWIND $rows AS row RETURN row',
                   'MATCH(n:Node {id: row.node_id}) SET n.embedding = row.embedding', 
                    {batchSize:1000, parallel:true, params: {rows,$rows}})
    """
    
    #query = '''UNWIND $rows AS row
    #           MATCH (n:Node {id: row.node_id})
    #           SET n.embedding = row.embedding
    #'''
    
    return insert_data(query, rows, batch_size)


def insert_data(query, rows, batch_size = 100000):
    # Function to handle the updating the Neo4j database in batch mode.

    total = 0
    batch = 0
    start = time.time()
    result = None

    while batch * batch_size < len(rows):

        res = conn.query(query, parameters={'rows': rows[batch*batch_size:(batch+1)*batch_size].to_dict('records')})
        try:
            total += res[0]['total']
        except:
            print(res)
        batch += 1
        result = {"total":total, "batches":batch, "time":time.time()-start}
        print(result)

    return result

# %%
# %%time
add_nodes(node_df_dedup)
# Out:
# {'total': 100000, 'batches': 1, 'time': 6.1925506591796875}
# {'total': 200000, 'batches': 2, 'time': 10.378504037857056}
# {'total': 300000, 'batches': 3, 'time': 14.053556442260742}
# {'total': 400000, 'batches': 4, 'time': 18.04265284538269}
# {'total': 500000, 'batches': 5, 'time': 22.34262180328369}
# {'total': 600000, 'batches': 6, 'time': 26.126931190490723}
# {'total': 700000, 'batches': 7, 'time': 29.86059880256653}
# {'total': 800000, 'batches': 8, 'time': 34.584617376327515}
# {'total': 900000, 'batches': 9, 'time': 38.3093957901001}
# {'total': 1000000, 'batches': 10, 'time': 41.988617181777954}
# {'total': 1100000, 'batches': 11, 'time': 45.79384732246399}
# {'total': 1200000, 'batches': 12, 'time': 49.445215463638306}
# {'total': 1300000, 'batches': 13, 'time': 53.07652926445007}
# {'total': 1400000, 'batches': 14, 'time': 56.753628969192505}
# {'total': 1500000, 'batches': 15, 'time': 60.392677545547485}
# {'total': 1600000, 'batches': 16, 'time': 64.07553052902222}
# {'total': 1700000, 'batches': 17, 'time': 67.74653506278992}
# {'total': 1800000, 'batches': 18, 'time': 71.49402022361755}
# {'total': 1900000, 'batches': 19, 'time': 75.80035591125488}
# {'total': 2000000, 'batches': 20, 'time': 80.29144024848938}
# {'total': 2100000, 'batches': 21, 'time': 84.65368986129761}
# {'total': 2200000, 'batches': 22, 'time': 88.27037167549133}
# {'total': 2300000, 'batches': 23, 'time': 91.98745131492615}
# {'total': 2400000, 'batches': 24, 'time': 96.0958993434906}
# {'total': 2500000, 'batches': 25, 'time': 100.14218711853027}
# {'total': 2600000, 'batches': 26, 'time': 103.83214449882507}
# {'total': 2700000, 'batches': 27, 'time': 107.43295645713806}
# {'total': 2800000, 'batches': 28, 'time': 111.07486486434937}
# {'total': 2900000, 'batches': 29, 'time': 115.12757325172424}
# {'total': 3000000, 'batches': 30, 'time': 119.11057162284851}
# {'total': 3100000, 'batches': 31, 'time': 122.90347647666931}
# {'total': 3200000, 'batches': 32, 'time': 126.5861189365387}
# {'total': 3300000, 'batches': 33, 'time': 130.25024938583374}
# {'total': 3400000, 'batches': 34, 'time': 133.92787265777588}
# {'total': 3500000, 'batches': 35, 'time': 137.60527276992798}
# {'total': 3600000, 'batches': 36, 'time': 141.16707515716553}
# {'total': 3700000, 'batches': 37, 'time': 144.76295948028564}
# {'total': 3800000, 'batches': 38, 'time': 148.39169716835022}
# {'total': 3900000, 'batches': 39, 'time': 151.99239683151245}
# {'total': 4000000, 'batches': 40, 'time': 155.55350708961487}
# {'total': 4100000, 'batches': 41, 'time': 159.11217427253723}
# {'total': 4200000, 'batches': 42, 'time': 162.76755118370056}
# {'total': 4300000, 'batches': 43, 'time': 166.3656439781189}
# {'total': 4400000, 'batches': 44, 'time': 169.91505908966064}
# {'total': 4500000, 'batches': 45, 'time': 173.58379864692688}
# {'total': 4600000, 'batches': 46, 'time': 177.62090754508972}
# {'total': 4700000, 'batches': 47, 'time': 181.8386242389679}
# {'total': 4800000, 'batches': 48, 'time': 185.52530646324158}
# {'total': 4900000, 'batches': 49, 'time': 189.45438194274902}
# {'total': 5000000, 'batches': 50, 'time': 193.46517539024353}
# {'total': 5100000, 'batches': 51, 'time': 197.3858790397644}
# {'total': 5200000, 'batches': 52, 'time': 201.0129783153534}
# {'total': 5300000, 'batches': 53, 'time': 204.7074418067932}
# {'total': 5400000, 'batches': 54, 'time': 208.51969957351685}
# {'total': 5500000, 'batches': 55, 'time': 212.07889008522034}
# {'total': 5600000, 'batches': 56, 'time': 215.59282112121582}
# {'total': 5700000, 'batches': 57, 'time': 219.16650366783142}
# {'total': 5800000, 'batches': 58, 'time': 222.72819638252258}
# {'total': 5900000, 'batches': 59, 'time': 226.38114976882935}
# {'total': 6000000, 'batches': 60, 'time': 230.06865763664246}
# {'total': 6100000, 'batches': 61, 'time': 233.7292640209198}
# {'total': 6200000, 'batches': 62, 'time': 237.41506457328796}
# {'total': 6300000, 'batches': 63, 'time': 241.17110538482666}
# {'total': 6400000, 'batches': 64, 'time': 244.84529280662537}
# {'total': 6500000, 'batches': 65, 'time': 248.48399710655212}
# {'total': 6600000, 'batches': 66, 'time': 252.15660977363586}
# {'total': 6700000, 'batches': 67, 'time': 255.9537217617035}
# {'total': 6800000, 'batches': 68, 'time': 259.8901677131653}
# {'total': 6900000, 'batches': 69, 'time': 263.54320430755615}
# {'total': 7000000, 'batches': 70, 'time': 267.2247304916382}
# {'total': 7100000, 'batches': 71, 'time': 270.9704282283783}
# {'total': 7200000, 'batches': 72, 'time': 274.6454837322235}
# {'total': 7300000, 'batches': 73, 'time': 278.3708288669586}
# {'total': 7400000, 'batches': 74, 'time': 282.6928188800812}
# {'total': 7500000, 'batches': 75, 'time': 286.6228835582733}
# {'total': 7600000, 'batches': 76, 'time': 290.25873470306396}
# {'total': 7700000, 'batches': 77, 'time': 294.4187686443329}
# {'total': 7800000, 'batches': 78, 'time': 298.1321837902069}
# {'total': 7900000, 'batches': 79, 'time': 301.9760980606079}
# {'total': 8000000, 'batches': 80, 'time': 306.0361375808716}
# {'total': 8100000, 'batches': 81, 'time': 309.6723666191101}
# {'total': 8200000, 'batches': 82, 'time': 313.3597481250763}
# {'total': 8300000, 'batches': 83, 'time': 317.0479612350464}
# {'total': 8400000, 'batches': 84, 'time': 320.97152161598206}
# {'total': 8500000, 'batches': 85, 'time': 324.5506875514984}
# {'total': 8600000, 'batches': 86, 'time': 328.1064167022705}
# {'total': 8700000, 'batches': 87, 'time': 331.64870953559875}
# {'total': 8800000, 'batches': 88, 'time': 335.3189444541931}
# {'total': 8900000, 'batches': 89, 'time': 338.8256711959839}
# {'total': 9000000, 'batches': 90, 'time': 342.3287024497986}
# {'total': 9100000, 'batches': 91, 'time': 345.86895871162415}
# {'total': 9200000, 'batches': 92, 'time': 349.5158371925354}
# {'total': 9300000, 'batches': 93, 'time': 353.0620617866516}
# {'total': 9400000, 'batches': 94, 'time': 356.707172870636}
# {'total': 9500000, 'batches': 95, 'time': 360.4115777015686}
# {'total': 9600000, 'batches': 96, 'time': 364.1115622520447}
# {'total': 9700000, 'batches': 97, 'time': 367.7538843154907}
# {'total': 9800000, 'batches': 98, 'time': 371.4367907047272}
# {'total': 9900000, 'batches': 99, 'time': 375.12101435661316}
# {'total': 10000000, 'batches': 100, 'time': 378.8569407463074}
# {'total': 10100000, 'batches': 101, 'time': 382.4851543903351}
# {'total': 10200000, 'batches': 102, 'time': 386.147789478302}
# {'total': 10300000, 'batches': 103, 'time': 389.8204915523529}
# {'total': 10400000, 'batches': 104, 'time': 393.53286147117615}
# {'total': 10500000, 'batches': 105, 'time': 397.2222330570221}
# {'total': 10600000, 'batches': 106, 'time': 400.84611415863037}
# {'total': 10700000, 'batches': 107, 'time': 404.5180959701538}
# {'total': 10800000, 'batches': 108, 'time': 408.26410818099976}
# {'total': 10900000, 'batches': 109, 'time': 411.9303512573242}
# {'total': 11000000, 'batches': 110, 'time': 415.6108195781708}
# {'total': 11100000, 'batches': 111, 'time': 419.31929302215576}
# {'total': 11200000, 'batches': 112, 'time': 423.03750443458557}
# {'total': 11300000, 'batches': 113, 'time': 426.7351415157318}
# {'total': 11400000, 'batches': 114, 'time': 430.40693378448486}
# {'total': 11500000, 'batches': 115, 'time': 434.0787603855133}
# {'total': 11600000, 'batches': 116, 'time': 437.8020374774933}
# {'total': 11700000, 'batches': 117, 'time': 441.4551966190338}
# {'total': 11800000, 'batches': 118, 'time': 445.10756063461304}
# {'total': 11900000, 'batches': 119, 'time': 448.9662492275238}
# {'total': 12000000, 'batches': 120, 'time': 452.6916947364807}
# {'total': 12100000, 'batches': 121, 'time': 456.46801948547363}
# {'total': 12200000, 'batches': 122, 'time': 460.22330379486084}
# {'total': 12300000, 'batches': 123, 'time': 464.32657194137573}
# {'total': 12400000, 'batches': 124, 'time': 467.935462474823}
# {'total': 12500000, 'batches': 125, 'time': 471.531578540802}
# {'total': 12600000, 'batches': 126, 'time': 475.2938013076782}
# {'total': 12700000, 'batches': 127, 'time': 478.89401745796204}
# {'total': 12800000, 'batches': 128, 'time': 482.3876700401306}
# {'total': 12900000, 'batches': 129, 'time': 485.9275953769684}
# {'total': 13000000, 'batches': 130, 'time': 489.7527480125427}
# {'total': 13100000, 'batches': 131, 'time': 493.76957654953003}
# {'total': 13200000, 'batches': 132, 'time': 497.73167872428894}
# {'total': 13300000, 'batches': 133, 'time': 501.29898977279663}
# {'total': 13400000, 'batches': 134, 'time': 504.8205602169037}
# {'total': 13500000, 'batches': 135, 'time': 508.361314535141}
# {'total': 13600000, 'batches': 136, 'time': 511.8686714172363}
# {'total': 13700000, 'batches': 137, 'time': 515.4013965129852}
# {'total': 13800000, 'batches': 138, 'time': 519.3012487888336}
# {'total': 13900000, 'batches': 139, 'time': 522.8641574382782}
# {'total': 14000000, 'batches': 140, 'time': 526.635379076004}
# {'total': 14100000, 'batches': 141, 'time': 530.1346879005432}
# {'total': 14200000, 'batches': 142, 'time': 533.809427022934}
# {'total': 14300000, 'batches': 143, 'time': 537.3486361503601}
# {'total': 14400000, 'batches': 144, 'time': 540.9757976531982}
# {'total': 14500000, 'batches': 145, 'time': 544.4831440448761}
# {'total': 14600000, 'batches': 146, 'time': 548.004890203476}
# {'total': 14700000, 'batches': 147, 'time': 551.7071452140808}
# {'total': 14800000, 'batches': 148, 'time': 555.2012765407562}
# {'total': 14900000, 'batches': 149, 'time': 558.6748514175415}
# {'total': 15000000, 'batches': 150, 'time': 562.2472577095032}
# {'total': 15100000, 'batches': 151, 'time': 565.750458240509}
# {'total': 15200000, 'batches': 152, 'time': 569.2303354740143}
# {'total': 15300000, 'batches': 153, 'time': 572.812465429306}
# {'total': 15400000, 'batches': 154, 'time': 576.3300714492798}
# {'total': 15500000, 'batches': 155, 'time': 579.8065102100372}
# {'total': 15600000, 'batches': 156, 'time': 583.4049479961395}
# {'total': 15700000, 'batches': 157, 'time': 586.9115791320801}
# {'total': 15800000, 'batches': 158, 'time': 590.4046490192413}
# {'total': 15900000, 'batches': 159, 'time': 593.8665769100189}
# {'total': 16000000, 'batches': 160, 'time': 597.5585551261902}
# {'total': 16100000, 'batches': 161, 'time': 601.2098307609558}
# {'total': 16200000, 'batches': 162, 'time': 604.8534092903137}
# {'total': 16300000, 'batches': 163, 'time': 608.4843394756317}
# {'total': 16400000, 'batches': 164, 'time': 612.2545640468597}
# {'total': 16500000, 'batches': 165, 'time': 615.9823410511017}
# {'total': 16600000, 'batches': 166, 'time': 619.6092295646667}
# {'total': 16700000, 'batches': 167, 'time': 623.2776801586151}
# {'total': 16800000, 'batches': 168, 'time': 627.0976691246033}
# {'total': 16900000, 'batches': 169, 'time': 630.736902475357}
# {'total': 17000000, 'batches': 170, 'time': 634.4283134937286}
# {'total': 17100000, 'batches': 171, 'time': 638.0956311225891}
# {'total': 17200000, 'batches': 172, 'time': 641.7612962722778}
# {'total': 17300000, 'batches': 173, 'time': 645.5849771499634}
# {'total': 17400000, 'batches': 174, 'time': 649.2424809932709}
# {'total': 17500000, 'batches': 175, 'time': 652.9488227367401}
# {'total': 17600000, 'batches': 176, 'time': 656.6161272525787}
# {'total': 17700000, 'batches': 177, 'time': 660.3191423416138}
# {'total': 17800000, 'batches': 178, 'time': 664.0490055084229}
# {'total': 17900000, 'batches': 179, 'time': 667.7487230300903}
# {'total': 18000000, 'batches': 180, 'time': 671.415625333786}
# {'total': 18100000, 'batches': 181, 'time': 675.0628354549408}
# {'total': 18200000, 'batches': 182, 'time': 678.6957848072052}
# {'total': 18300000, 'batches': 183, 'time': 682.41912150383}
# {'total': 18400000, 'batches': 184, 'time': 686.1064808368683}
# {'total': 18500000, 'batches': 185, 'time': 689.7526347637177}
# {'total': 18600000, 'batches': 186, 'time': 693.3854048252106}
# {'total': 18700000, 'batches': 187, 'time': 696.9958794116974}
# {'total': 18800000, 'batches': 188, 'time': 700.7499549388885}
# {'total': 18900000, 'batches': 189, 'time': 704.4613585472107}
# {'total': 19000000, 'batches': 190, 'time': 708.1311330795288}
# {'total': 19100000, 'batches': 191, 'time': 711.7903399467468}
# {'total': 19200000, 'batches': 192, 'time': 715.4242081642151}
# {'total': 19300000, 'batches': 193, 'time': 719.376761674881}
# {'total': 19400000, 'batches': 194, 'time': 723.0424792766571}
# {'total': 19500000, 'batches': 195, 'time': 726.7471182346344}
# {'total': 19600000, 'batches': 196, 'time': 730.464855670929}
# {'total': 19700000, 'batches': 197, 'time': 734.3150475025177}
# {'total': 19800000, 'batches': 198, 'time': 738.2262539863586}
# {'total': 19900000, 'batches': 199, 'time': 741.8578677177429}
# {'total': 20000000, 'batches': 200, 'time': 745.5282695293427}
# {'total': 20100000, 'batches': 201, 'time': 749.3376955986023}
# {'total': 20200000, 'batches': 202, 'time': 753.2714779376984}
# {'total': 20300000, 'batches': 203, 'time': 757.0360355377197}
# {'total': 20400000, 'batches': 204, 'time': 760.6986587047577}
# {'total': 20500000, 'batches': 205, 'time': 764.404757976532}
# {'total': 20600000, 'batches': 206, 'time': 768.2467610836029}
# {'total': 20700000, 'batches': 207, 'time': 771.970974445343}
# {'total': 20800000, 'batches': 208, 'time': 775.6349654197693}
# {'total': 20900000, 'batches': 209, 'time': 779.2750632762909}
# {'total': 21000000, 'batches': 210, 'time': 783.2958545684814}
# {'total': 21100000, 'batches': 211, 'time': 786.9630882740021}
# {'total': 21200000, 'batches': 212, 'time': 790.6906986236572}
# {'total': 21300000, 'batches': 213, 'time': 794.4162330627441}
# {'total': 21400000, 'batches': 214, 'time': 798.3997569084167}
# {'total': 21500000, 'batches': 215, 'time': 802.0754914283752}
# {'total': 21600000, 'batches': 216, 'time': 805.7311735153198}
# {'total': 21700000, 'batches': 217, 'time': 809.4444530010223}
# {'total': 21800000, 'batches': 218, 'time': 813.2886555194855}
# {'total': 21900000, 'batches': 219, 'time': 816.9471652507782}
# {'total': 22000000, 'batches': 220, 'time': 820.5973987579346}
# {'total': 22100000, 'batches': 221, 'time': 824.602356672287}
# {'total': 22200000, 'batches': 222, 'time': 828.2880365848541}
# {'total': 22300000, 'batches': 223, 'time': 831.9513838291168}
# {'total': 22400000, 'batches': 224, 'time': 835.5909421443939}
# {'total': 22500000, 'batches': 225, 'time': 839.4180912971497}
# {'total': 22600000, 'batches': 226, 'time': 843.1156711578369}
# {'total': 22700000, 'batches': 227, 'time': 846.7542586326599}
# {'total': 22800000, 'batches': 228, 'time': 850.3678743839264}
# {'total': 22900000, 'batches': 229, 'time': 854.108149766922}
# {'total': 23000000, 'batches': 230, 'time': 857.785083770752}
# {'total': 23100000, 'batches': 231, 'time': 861.4600050449371}
# {'total': 23200000, 'batches': 232, 'time': 865.146963596344}
# {'total': 23300000, 'batches': 233, 'time': 868.8327922821045}
# {'total': 23400000, 'batches': 234, 'time': 872.4435725212097}
# {'total': 23500000, 'batches': 235, 'time': 875.9573998451233}
# {'total': 23600000, 'batches': 236, 'time': 879.476455450058}
# {'total': 23700000, 'batches': 237, 'time': 883.0669476985931}
# {'total': 23800000, 'batches': 238, 'time': 886.5280945301056}
# {'total': 23900000, 'batches': 239, 'time': 889.9751272201538}
# {'total': 24000000, 'batches': 240, 'time': 893.5011434555054}
# {'total': 24100000, 'batches': 241, 'time': 897.1495809555054}
# {'total': 24200000, 'batches': 242, 'time': 900.6528344154358}
# {'total': 24300000, 'batches': 243, 'time': 904.1095190048218}
# {'total': 24400000, 'batches': 244, 'time': 907.64803647995}
# {'total': 24500000, 'batches': 245, 'time': 911.2370314598083}
# {'total': 24600000, 'batches': 246, 'time': 914.7604022026062}
# {'total': 24700000, 'batches': 247, 'time': 918.2449259757996}
# {'total': 24800000, 'batches': 248, 'time': 921.7423298358917}
# {'total': 24900000, 'batches': 249, 'time': 925.2406785488129}
# {'total': 25000000, 'batches': 250, 'time': 928.7644736766815}
# {'total': 25100000, 'batches': 251, 'time': 932.3881630897522}
# {'total': 25200000, 'batches': 252, 'time': 935.907764673233}
# {'total': 25300000, 'batches': 253, 'time': 939.4022064208984}
# {'total': 25400000, 'batches': 254, 'time': 942.8867239952087}
# {'total': 25500000, 'batches': 255, 'time': 946.4991779327393}
# {'total': 25600000, 'batches': 256, 'time': 949.9881865978241}
# {'total': 25700000, 'batches': 257, 'time': 953.5045771598816}
# {'total': 25800000, 'batches': 258, 'time': 956.989887714386}
# {'total': 25900000, 'batches': 259, 'time': 960.489004611969}
# {'total': 26000000, 'batches': 260, 'time': 964.1889355182648}
# {'total': 26100000, 'batches': 261, 'time': 967.7087349891663}
# {'total': 26200000, 'batches': 262, 'time': 971.3319797515869}
# {'total': 26300000, 'batches': 263, 'time': 974.8380351066589}
# {'total': 26400000, 'batches': 264, 'time': 978.3470516204834}
# {'total': 26500000, 'batches': 265, 'time': 981.8481929302216}
# {'total': 26600000, 'batches': 266, 'time': 985.4365611076355}
# {'total': 26700000, 'batches': 267, 'time': 989.0163915157318}
# {'total': 26800000, 'batches': 268, 'time': 992.4894647598267}
# {'total': 26900000, 'batches': 269, 'time': 996.003066778183}
# {'total': 27000000, 'batches': 270, 'time': 999.4655649662018}
# {'total': 27100000, 'batches': 271, 'time': 1003.0323770046234}
# {'total': 27200000, 'batches': 272, 'time': 1006.5024735927582}
# {'total': 27300000, 'batches': 273, 'time': 1010.0050346851349}
# {'total': 27400000, 'batches': 274, 'time': 1013.6211929321289}
# {'total': 27500000, 'batches': 275, 'time': 1017.1000249385834}
# {'total': 27600000, 'batches': 276, 'time': 1020.5987191200256}
# {'total': 27700000, 'batches': 277, 'time': 1024.1894743442535}
# {'total': 27800000, 'batches': 278, 'time': 1027.6303157806396}
# {'total': 27900000, 'batches': 279, 'time': 1031.2493698596954}
# {'total': 28000000, 'batches': 280, 'time': 1034.7117884159088}
# {'total': 28100000, 'batches': 281, 'time': 1038.2116572856903}
# {'total': 28200000, 'batches': 282, 'time': 1041.6794555187225}
# {'total': 28300000, 'batches': 283, 'time': 1045.1687850952148}
# {'total': 28400000, 'batches': 284, 'time': 1048.7502212524414}
# {'total': 28500000, 'batches': 285, 'time': 1052.379613161087}
# {'total': 28600000, 'batches': 286, 'time': 1055.8747482299805}
# {'total': 28700000, 'batches': 287, 'time': 1059.446592092514}
# {'total': 28800000, 'batches': 288, 'time': 1062.9765615463257}
# {'total': 28900000, 'batches': 289, 'time': 1066.5187101364136}
# {'total': 29000000, 'batches': 290, 'time': 1070.063416004181}
# {'total': 29100000, 'batches': 291, 'time': 1073.5470776557922}
# {'total': 29200000, 'batches': 292, 'time': 1077.0301496982574}
# {'total': 29300000, 'batches': 293, 'time': 1080.5096151828766}
# {'total': 29400000, 'batches': 294, 'time': 1084.0611946582794}
# {'total': 29500000, 'batches': 295, 'time': 1087.626267671585}
# {'total': 29600000, 'batches': 296, 'time': 1091.1815328598022}
# {'total': 29700000, 'batches': 297, 'time': 1094.6777126789093}
# {'total': 29800000, 'batches': 298, 'time': 1098.1592524051666}
# {'total': 29900000, 'batches': 299, 'time': 1101.606546163559}
# {'total': 30000000, 'batches': 300, 'time': 1105.2437999248505}
# {'total': 30100000, 'batches': 301, 'time': 1108.938336610794}
# {'total': 30200000, 'batches': 302, 'time': 1112.4917631149292}
# {'total': 30300000, 'batches': 303, 'time': 1115.986961364746}
# {'total': 30400000, 'batches': 304, 'time': 1119.5192182064056}
# {'total': 30500000, 'batches': 305, 'time': 1123.0484874248505}
# {'total': 30600000, 'batches': 306, 'time': 1126.713073015213}
# {'total': 30700000, 'batches': 307, 'time': 1130.2346954345703}
# {'total': 30800000, 'batches': 308, 'time': 1133.7977185249329}
# {'total': 30900000, 'batches': 309, 'time': 1137.3119885921478}
# {'total': 31000000, 'batches': 310, 'time': 1140.856790304184}
# {'total': 31100000, 'batches': 311, 'time': 1144.44659948349}
# {'total': 31200000, 'batches': 312, 'time': 1147.9905529022217}
# {'total': 31300000, 'batches': 313, 'time': 1151.5322098731995}
# {'total': 31400000, 'batches': 314, 'time': 1155.0708553791046}
# {'total': 31500000, 'batches': 315, 'time': 1158.7083265781403}
# {'total': 31600000, 'batches': 316, 'time': 1162.3546628952026}
# {'total': 31700000, 'batches': 317, 'time': 1165.8941547870636}
# {'total': 31800000, 'batches': 318, 'time': 1169.471585035324}
# {'total': 31900000, 'batches': 319, 'time': 1172.9793553352356}
# {'total': 32000000, 'batches': 320, 'time': 1176.5077447891235}
# {'total': 32100000, 'batches': 321, 'time': 1180.1054825782776}
# {'total': 32200000, 'batches': 322, 'time': 1183.6622455120087}
# {'total': 32300000, 'batches': 323, 'time': 1187.198009967804}
# {'total': 32400000, 'batches': 324, 'time': 1190.7470378875732}
# {'total': 32500000, 'batches': 325, 'time': 1194.701863527298}
# {'total': 32600000, 'batches': 326, 'time': 1198.4260432720184}
# {'total': 32700000, 'batches': 327, 'time': 1201.976821422577}
# {'total': 32800000, 'batches': 328, 'time': 1205.4902238845825}
# {'total': 32900000, 'batches': 329, 'time': 1209.067034959793}
# {'total': 33000000, 'batches': 330, 'time': 1212.559766292572}
# {'total': 33100000, 'batches': 331, 'time': 1216.069206237793}
# {'total': 33200000, 'batches': 332, 'time': 1219.9246499538422}
# {'total': 33300000, 'batches': 333, 'time': 1223.4792788028717}
# {'total': 33400000, 'batches': 334, 'time': 1227.0063796043396}
# {'total': 33500000, 'batches': 335, 'time': 1230.529676437378}
# {'total': 33600000, 'batches': 336, 'time': 1234.4366836547852}
# {'total': 33700000, 'batches': 337, 'time': 1237.9348423480988}
# {'total': 33800000, 'batches': 338, 'time': 1241.6338534355164}
# {'total': 33900000, 'batches': 339, 'time': 1245.1218910217285}
# {'total': 34000000, 'batches': 340, 'time': 1248.7098741531372}
# {'total': 34100000, 'batches': 341, 'time': 1252.2699778079987}
# {'total': 34200000, 'batches': 342, 'time': 1255.988828420639}
# {'total': 34300000, 'batches': 343, 'time': 1259.525648355484}
# {'total': 34400000, 'batches': 344, 'time': 1263.0209159851074}
# {'total': 34500000, 'batches': 345, 'time': 1266.6781747341156}
# {'total': 34600000, 'batches': 346, 'time': 1270.3412947654724}
# {'total': 34700000, 'batches': 347, 'time': 1273.8213951587677}
# {'total': 34800000, 'batches': 348, 'time': 1277.5030970573425}
# {'total': 34900000, 'batches': 349, 'time': 1281.040423631668}
# {'total': 35000000, 'batches': 350, 'time': 1284.653814792633}
# {'total': 35100000, 'batches': 351, 'time': 1288.2197370529175}
# {'total': 35200000, 'batches': 352, 'time': 1291.7553329467773}
# {'total': 35300000, 'batches': 353, 'time': 1295.335265636444}
# {'total': 35400000, 'batches': 354, 'time': 1298.8699963092804}
# {'total': 35500000, 'batches': 355, 'time': 1302.5140633583069}
# {'total': 35600000, 'batches': 356, 'time': 1306.004907131195}
# {'total': 35700000, 'batches': 357, 'time': 1309.616460800171}
# {'total': 35800000, 'batches': 358, 'time': 1313.2200977802277}
# {'total': 35900000, 'batches': 359, 'time': 1316.7664573192596}
# {'total': 36000000, 'batches': 360, 'time': 1320.266825914383}
# {'total': 36100000, 'batches': 361, 'time': 1323.8526773452759}
# {'total': 36200000, 'batches': 362, 'time': 1327.4824163913727}
# {'total': 36300000, 'batches': 363, 'time': 1330.976496219635}
# {'total': 36400000, 'batches': 364, 'time': 1334.4799010753632}
# {'total': 36500000, 'batches': 365, 'time': 1338.02712392807}
# {'total': 36600000, 'batches': 366, 'time': 1341.510891199112}
# {'total': 36700000, 'batches': 367, 'time': 1345.0100679397583}
# {'total': 36800000, 'batches': 368, 'time': 1348.538377046585}
# {'total': 36900000, 'batches': 369, 'time': 1352.1562724113464}
# {'total': 37000000, 'batches': 370, 'time': 1355.659007549286}
# {'total': 37100000, 'batches': 371, 'time': 1359.1611835956573}
# {'total': 37200000, 'batches': 372, 'time': 1362.660576581955}
# {'total': 37300000, 'batches': 373, 'time': 1366.3101952075958}
# {'total': 37400000, 'batches': 374, 'time': 1369.8110237121582}
# {'total': 37500000, 'batches': 375, 'time': 1373.310077905655}
# {'total': 37600000, 'batches': 376, 'time': 1376.78644323349}
# {'total': 37700000, 'batches': 377, 'time': 1380.6422204971313}
# {'total': 37800000, 'batches': 378, 'time': 1384.2101066112518}
# {'total': 37900000, 'batches': 379, 'time': 1387.7111067771912}
# {'total': 38000000, 'batches': 380, 'time': 1391.2815146446228}
# {'total': 38100000, 'batches': 381, 'time': 1394.8175556659698}
# {'total': 38200000, 'batches': 382, 'time': 1398.3138217926025}
# {'total': 38300000, 'batches': 383, 'time': 1401.8983299732208}
# {'total': 38400000, 'batches': 384, 'time': 1405.5607776641846}
# {'total': 38500000, 'batches': 385, 'time': 1409.0271797180176}
# {'total': 38600000, 'batches': 386, 'time': 1412.533879518509}
# {'total': 38700000, 'batches': 387, 'time': 1415.988097190857}
# {'total': 38800000, 'batches': 388, 'time': 1419.5768885612488}
# {'total': 38900000, 'batches': 389, 'time': 1423.0928416252136}
# {'total': 39000000, 'batches': 390, 'time': 1426.5439610481262}
# {'total': 39100000, 'batches': 391, 'time': 1430.015353679657}
# {'total': 39200000, 'batches': 392, 'time': 1433.4666709899902}
# {'total': 39300000, 'batches': 393, 'time': 1437.0849628448486}
# {'total': 39400000, 'batches': 394, 'time': 1440.67094540596}
# {'total': 39500000, 'batches': 395, 'time': 1444.1205794811249}
# {'total': 39600000, 'batches': 396, 'time': 1447.5834197998047}
# {'total': 39700000, 'batches': 397, 'time': 1451.0905997753143}
# {'total': 39800000, 'batches': 398, 'time': 1454.5771751403809}
# {'total': 39900000, 'batches': 399, 'time': 1458.3173367977142}
# {'total': 40000000, 'batches': 400, 'time': 1461.8284318447113}
# {'total': 40100000, 'batches': 401, 'time': 1465.2899377346039}
# {'total': 40200000, 'batches': 402, 'time': 1468.7548670768738}
# {'total': 40300000, 'batches': 403, 'time': 1472.2714354991913}
# {'total': 40400000, 'batches': 404, 'time': 1475.8804733753204}
# {'total': 40500000, 'batches': 405, 'time': 1479.327196598053}
# {'total': 40600000, 'batches': 406, 'time': 1482.7664868831635}
# {'total': 40700000, 'batches': 407, 'time': 1486.260579109192}
# {'total': 40800000, 'batches': 408, 'time': 1489.7704374790192}
# {'total': 40900000, 'batches': 409, 'time': 1493.2991552352905}
# {'total': 41000000, 'batches': 410, 'time': 1496.77898645401}
# {'total': 41100000, 'batches': 411, 'time': 1500.2573008537292}
# {'total': 41200000, 'batches': 412, 'time': 1503.7399702072144}
# {'total': 41300000, 'batches': 413, 'time': 1507.2477042675018}
# {'total': 41400000, 'batches': 414, 'time': 1510.7113480567932}
# {'total': 41500000, 'batches': 415, 'time': 1514.242433309555}
# {'total': 41600000, 'batches': 416, 'time': 1517.7726275920868}
# {'total': 41700000, 'batches': 417, 'time': 1521.2535653114319}
# {'total': 41800000, 'batches': 418, 'time': 1524.7413461208344}
# {'total': 41900000, 'batches': 419, 'time': 1528.6697018146515}
# {'total': 42000000, 'batches': 420, 'time': 1532.8229229450226}
# {'total': 42100000, 'batches': 421, 'time': 1536.3077130317688}
# {'total': 42200000, 'batches': 422, 'time': 1539.8640305995941}
# {'total': 42300000, 'batches': 423, 'time': 1543.3334188461304}
# {'total': 42400000, 'batches': 424, 'time': 1546.7904801368713}
# {'total': 42500000, 'batches': 425, 'time': 1550.327537536621}
# {'total': 42600000, 'batches': 426, 'time': 1554.0444779396057}
# {'total': 42700000, 'batches': 427, 'time': 1557.6056954860687}
# {'total': 42800000, 'batches': 428, 'time': 1561.0542345046997}
# {'total': 42900000, 'batches': 429, 'time': 1564.5759472846985}
# {'total': 43000000, 'batches': 430, 'time': 1568.1664144992828}
# {'total': 43100000, 'batches': 431, 'time': 1571.675085067749}
# {'total': 43200000, 'batches': 432, 'time': 1575.1402416229248}
# {'total': 43300000, 'batches': 433, 'time': 1579.0071396827698}
# {'total': 43400000, 'batches': 434, 'time': 1582.4606704711914}
# {'total': 43500000, 'batches': 435, 'time': 1586.007704257965}
# {'total': 43600000, 'batches': 436, 'time': 1589.4934446811676}
# {'total': 43700000, 'batches': 437, 'time': 1592.9609439373016}
# {'total': 43800000, 'batches': 438, 'time': 1596.7805614471436}
# {'total': 43900000, 'batches': 439, 'time': 1600.2933583259583}
# {'total': 44000000, 'batches': 440, 'time': 1603.98575425148}
# {'total': 44100000, 'batches': 441, 'time': 1607.6144864559174}
# {'total': 44200000, 'batches': 442, 'time': 1611.0783610343933}
# {'total': 44300000, 'batches': 443, 'time': 1614.6407134532928}
# {'total': 44400000, 'batches': 444, 'time': 1618.2993021011353}
# {'total': 44500000, 'batches': 445, 'time': 1621.809936285019}
# {'total': 44600000, 'batches': 446, 'time': 1625.306757926941}
# {'total': 44700000, 'batches': 447, 'time': 1628.7716174125671}
# {'total': 44800000, 'batches': 448, 'time': 1632.2520580291748}
# {'total': 44900000, 'batches': 449, 'time': 1635.86541056633}
# {'total': 45000000, 'batches': 450, 'time': 1639.3890488147736}
# {'total': 45100000, 'batches': 451, 'time': 1642.9539670944214}
# {'total': 45200000, 'batches': 452, 'time': 1646.45281124115}
# {'total': 45300000, 'batches': 453, 'time': 1649.9212713241577}
# {'total': 45400000, 'batches': 454, 'time': 1653.5618727207184}
# {'total': 45500000, 'batches': 455, 'time': 1657.387549161911}
# {'total': 45600000, 'batches': 456, 'time': 1660.9900488853455}
# {'total': 45700000, 'batches': 457, 'time': 1664.7191545963287}
# {'total': 45800000, 'batches': 458, 'time': 1668.445872783661}
# {'total': 45900000, 'batches': 459, 'time': 1672.1407489776611}
# {'total': 46000000, 'batches': 460, 'time': 1675.9021320343018}
# {'total': 46100000, 'batches': 461, 'time': 1679.5710668563843}
# {'total': 46200000, 'batches': 462, 'time': 1683.4356832504272}
# {'total': 46300000, 'batches': 463, 'time': 1687.6101496219635}
# {'total': 46400000, 'batches': 464, 'time': 1691.286302804947}
# {'total': 46500000, 'batches': 465, 'time': 1695.0302259922028}
# {'total': 46600000, 'batches': 466, 'time': 1698.7066807746887}
# {'total': 46700000, 'batches': 467, 'time': 1702.3986945152283}
# {'total': 46800000, 'batches': 468, 'time': 1706.1469423770905}
# {'total': 46900000, 'batches': 469, 'time': 1709.789912700653}
# {'total': 47000000, 'batches': 470, 'time': 1713.4991297721863}
# {'total': 47100000, 'batches': 471, 'time': 1717.224373102188}
# {'total': 47200000, 'batches': 472, 'time': 1720.957290172577}
# {'total': 47300000, 'batches': 473, 'time': 1724.6264452934265}
# {'total': 47400000, 'batches': 474, 'time': 1728.3173987865448}
# {'total': 47500000, 'batches': 475, 'time': 1731.9598529338837}
# {'total': 47600000, 'batches': 476, 'time': 1735.4967353343964}
# {'total': 47700000, 'batches': 477, 'time': 1738.9922370910645}
# {'total': 47800000, 'batches': 478, 'time': 1742.5919454097748}
# {'total': 47900000, 'batches': 479, 'time': 1746.1259286403656}
# {'total': 48000000, 'batches': 480, 'time': 1749.638423204422}
# {'total': 48100000, 'batches': 481, 'time': 1753.1379477977753}
# {'total': 48200000, 'batches': 482, 'time': 1756.7419247627258}
# {'total': 48300000, 'batches': 483, 'time': 1760.2841606140137}
# {'total': 48400000, 'batches': 484, 'time': 1763.8046135902405}
# {'total': 48500000, 'batches': 485, 'time': 1767.3336117267609}
# {'total': 48600000, 'batches': 486, 'time': 1770.861925125122}
# {'total': 48700000, 'batches': 487, 'time': 1774.4535179138184}
# {'total': 48800000, 'batches': 488, 'time': 1778.056908607483}
# {'total': 48900000, 'batches': 489, 'time': 1781.6160995960236}
# {'total': 49000000, 'batches': 490, 'time': 1785.1165962219238}
# {'total': 49100000, 'batches': 491, 'time': 1788.6276457309723}
# {'total': 49200000, 'batches': 492, 'time': 1792.2305204868317}
# {'total': 49300000, 'batches': 493, 'time': 1795.7935438156128}
# {'total': 49400000, 'batches': 494, 'time': 1799.312264919281}
# {'total': 49500000, 'batches': 495, 'time': 1802.802879333496}
# {'total': 49600000, 'batches': 496, 'time': 1806.3165559768677}
# {'total': 49700000, 'batches': 497, 'time': 1809.8871688842773}
# {'total': 49800000, 'batches': 498, 'time': 1813.3995728492737}
# {'total': 49900000, 'batches': 499, 'time': 1816.8790199756622}
# {'total': 50000000, 'batches': 500, 'time': 1820.3459861278534}
# {'total': 50100000, 'batches': 501, 'time': 1823.9085037708282}
# {'total': 50200000, 'batches': 502, 'time': 1827.390951871872}
# {'total': 50300000, 'batches': 503, 'time': 1830.8790278434753}
# {'total': 50400000, 'batches': 504, 'time': 1834.383355140686}
# {'total': 50500000, 'batches': 505, 'time': 1837.8324618339539}
# {'total': 50600000, 'batches': 506, 'time': 1841.4261577129364}
# {'total': 50700000, 'batches': 507, 'time': 1844.9005455970764}
# {'total': 50800000, 'batches': 508, 'time': 1848.4180765151978}
# {'total': 50900000, 'batches': 509, 'time': 1851.8866362571716}
# {'total': 51000000, 'batches': 510, 'time': 1855.331779718399}
# {'total': 51100000, 'batches': 511, 'time': 1858.915054321289}
# {'total': 51200000, 'batches': 512, 'time': 1862.4285173416138}
# {'total': 51300000, 'batches': 513, 'time': 1865.90119099617}
# {'total': 51400000, 'batches': 514, 'time': 1869.4059555530548}
# {'total': 51500000, 'batches': 515, 'time': 1872.9014060497284}
# {'total': 51600000, 'batches': 516, 'time': 1876.5841166973114}
# {'total': 51700000, 'batches': 517, 'time': 1880.0924036502838}
# {'total': 51800000, 'batches': 518, 'time': 1883.5638854503632}
# {'total': 51900000, 'batches': 519, 'time': 1887.0461688041687}
# {'total': 52000000, 'batches': 520, 'time': 1890.5364003181458}
# {'total': 52100000, 'batches': 521, 'time': 1894.1646480560303}
# {'total': 52200000, 'batches': 522, 'time': 1897.661031961441}
# {'total': 52300000, 'batches': 523, 'time': 1901.1444900035858}
# {'total': 52400000, 'batches': 524, 'time': 1904.6564013957977}
# {'total': 52500000, 'batches': 525, 'time': 1908.1632595062256}
# {'total': 52600000, 'batches': 526, 'time': 1911.694855928421}
# {'total': 52700000, 'batches': 527, 'time': 1915.2541029453278}
# {'total': 52800000, 'batches': 528, 'time': 1918.7187368869781}
# {'total': 52900000, 'batches': 529, 'time': 1922.1866962909698}
# {'total': 53000000, 'batches': 530, 'time': 1925.6533217430115}
# {'total': 53100000, 'batches': 531, 'time': 1929.120810508728}
# {'total': 53200000, 'batches': 532, 'time': 1932.6687076091766}
# {'total': 53300000, 'batches': 533, 'time': 1936.149842262268}
# {'total': 53400000, 'batches': 534, 'time': 1939.6575827598572}
# {'total': 53500000, 'batches': 535, 'time': 1943.1313679218292}
# {'total': 53600000, 'batches': 536, 'time': 1946.62788438797}
# {'total': 53700000, 'batches': 537, 'time': 1950.2660746574402}
# {'total': 53800000, 'batches': 538, 'time': 1953.755396604538}
# {'total': 53900000, 'batches': 539, 'time': 1957.278743982315}
# {'total': 54000000, 'batches': 540, 'time': 1960.7433104515076}
# {'total': 54100000, 'batches': 541, 'time': 1964.1893997192383}
# {'total': 54200000, 'batches': 542, 'time': 1967.8856327533722}
# {'total': 54300000, 'batches': 543, 'time': 1971.3672504425049}
# {'total': 54400000, 'batches': 544, 'time': 1974.8562541007996}
# {'total': 54500000, 'batches': 545, 'time': 1978.3410918712616}
# {'total': 54600000, 'batches': 546, 'time': 1982.4086780548096}
# {'total': 54700000, 'batches': 547, 'time': 1985.899088859558}
# {'total': 54800000, 'batches': 548, 'time': 1989.3553960323334}
# {'total': 54900000, 'batches': 549, 'time': 1992.819314956665}
# {'total': 55000000, 'batches': 550, 'time': 1996.5710883140564}
# {'total': 55100000, 'batches': 551, 'time': 2000.0821659564972}
# {'total': 55200000, 'batches': 552, 'time': 2003.5516443252563}
# {'total': 55300000, 'batches': 553, 'time': 2006.9987103939056}
# {'total': 55400000, 'batches': 554, 'time': 2010.6111578941345}
# {'total': 55500000, 'batches': 555, 'time': 2014.1455714702606}
# {'total': 55600000, 'batches': 556, 'time': 2017.6005449295044}
# {'total': 55700000, 'batches': 557, 'time': 2021.0894815921783}
# {'total': 55800000, 'batches': 558, 'time': 2024.7803056240082}
# {'total': 55900000, 'batches': 559, 'time': 2028.3122317790985}
# {'total': 56000000, 'batches': 560, 'time': 2031.7782452106476}
# {'total': 56100000, 'batches': 561, 'time': 2035.2721421718597}
# {'total': 56200000, 'batches': 562, 'time': 2038.948848247528}
# {'total': 56300000, 'batches': 563, 'time': 2042.3906168937683}
# {'total': 56400000, 'batches': 564, 'time': 2046.023849248886}
# {'total': 56500000, 'batches': 565, 'time': 2049.5248889923096}
# {'total': 56600000, 'batches': 566, 'time': 2053.0957815647125}
# {'total': 56700000, 'batches': 567, 'time': 2056.602361679077}
# {'total': 56800000, 'batches': 568, 'time': 2060.173547744751}
# {'total': 56900000, 'batches': 569, 'time': 2063.8225798606873}
# {'total': 57000000, 'batches': 570, 'time': 2067.332746744156}
# {'total': 57100000, 'batches': 571, 'time': 2070.7778272628784}
# {'total': 57200000, 'batches': 572, 'time': 2074.78946018219}
# {'total': 57300000, 'batches': 573, 'time': 2078.4892399311066}
# {'total': 57400000, 'batches': 574, 'time': 2081.9263365268707}
# {'total': 57500000, 'batches': 575, 'time': 2085.389726638794}
# {'total': 57600000, 'batches': 576, 'time': 2089.40851521492}
# {'total': 57700000, 'batches': 577, 'time': 2093.4103906154633}
# {'total': 57800000, 'batches': 578, 'time': 2097.0048751831055}
# {'total': 57900000, 'batches': 579, 'time': 2100.6610445976257}
# {'total': 58000000, 'batches': 580, 'time': 2104.366340637207}
# {'total': 58100000, 'batches': 581, 'time': 2107.981622695923}
# {'total': 58200000, 'batches': 582, 'time': 2111.5930156707764}
# {'total': 58300000, 'batches': 583, 'time': 2115.229257106781}
# {'total': 58400000, 'batches': 584, 'time': 2118.9371976852417}
# {'total': 58500000, 'batches': 585, 'time': 2122.5866556167603}
# {'total': 58600000, 'batches': 586, 'time': 2126.203033208847}
# {'total': 58700000, 'batches': 587, 'time': 2129.8921041488647}
# {'total': 58800000, 'batches': 588, 'time': 2133.5876376628876}
# {'total': 58900000, 'batches': 589, 'time': 2137.1663308143616}
# {'total': 59000000, 'batches': 590, 'time': 2140.734105348587}
# {'total': 59100000, 'batches': 591, 'time': 2144.2271502017975}
# {'total': 59200000, 'batches': 592, 'time': 2147.7603142261505}
# {'total': 59300000, 'batches': 593, 'time': 2151.603915452957}
# {'total': 59400000, 'batches': 594, 'time': 2155.1468255519867}
# {'total': 59500000, 'batches': 595, 'time': 2158.6230084896088}
# {'total': 59600000, 'batches': 596, 'time': 2162.126848936081}
# {'total': 59700000, 'batches': 597, 'time': 2165.729920387268}
# {'total': 59800000, 'batches': 598, 'time': 2169.277119398117}
# {'total': 59900000, 'batches': 599, 'time': 2172.7600395679474}
# {'total': 60000000, 'batches': 600, 'time': 2176.278708934784}
# {'total': 60100000, 'batches': 601, 'time': 2179.7745263576508}
# {'total': 60200000, 'batches': 602, 'time': 2183.266998767853}
# {'total': 60300000, 'batches': 603, 'time': 2186.785086631775}
# {'total': 60400000, 'batches': 604, 'time': 2190.3167645931244}
# {'total': 60500000, 'batches': 605, 'time': 2193.8360528945923}
# {'total': 60600000, 'batches': 606, 'time': 2197.4174325466156}
# {'total': 60700000, 'batches': 607, 'time': 2201.6748430728912}
# {'total': 60800000, 'batches': 608, 'time': 2205.665885448456}
# {'total': 60900000, 'batches': 609, 'time': 2209.5534195899963}
# {'total': 61000000, 'batches': 610, 'time': 2213.275404214859}
# {'total': 61100000, 'batches': 611, 'time': 2216.7885603904724}
# {'total': 61200000, 'batches': 612, 'time': 2220.3984479904175}
# {'total': 61300000, 'batches': 613, 'time': 2223.920578479767}
# {'total': 61400000, 'batches': 614, 'time': 2227.4088401794434}
# {'total': 61500000, 'batches': 615, 'time': 2230.9185819625854}
# {'total': 61600000, 'batches': 616, 'time': 2234.4143838882446}
# {'total': 61700000, 'batches': 617, 'time': 2237.9024107456207}
# {'total': 61800000, 'batches': 618, 'time': 2241.6628465652466}
# {'total': 61900000, 'batches': 619, 'time': 2245.698902606964}
# {'total': 62000000, 'batches': 620, 'time': 2249.9459125995636}
# {'total': 62100000, 'batches': 621, 'time': 2253.4067192077637}
# {'total': 62200000, 'batches': 622, 'time': 2256.9379963874817}
# {'total': 62300000, 'batches': 623, 'time': 2260.4667797088623}
# {'total': 62400000, 'batches': 624, 'time': 2263.9721739292145}
# {'total': 62500000, 'batches': 625, 'time': 2267.476530790329}
# {'total': 62600000, 'batches': 626, 'time': 2271.101909637451}
# {'total': 62700000, 'batches': 627, 'time': 2274.608114719391}
# {'total': 62800000, 'batches': 628, 'time': 2278.114691257477}
# {'total': 62900000, 'batches': 629, 'time': 2281.6578764915466}
# {'total': 63000000, 'batches': 630, 'time': 2285.3202798366547}
# {'total': 63100000, 'batches': 631, 'time': 2288.8542783260345}
# {'total': 63200000, 'batches': 632, 'time': 2292.8889060020447}
# {'total': 63300000, 'batches': 633, 'time': 2296.451549768448}
# {'total': 63400000, 'batches': 634, 'time': 2299.974606990814}
# {'total': 63500000, 'batches': 635, 'time': 2303.5358271598816}
# {'total': 63600000, 'batches': 636, 'time': 2307.2363374233246}
# {'total': 63700000, 'batches': 637, 'time': 2310.835146665573}
# {'total': 63800000, 'batches': 638, 'time': 2314.33514380455}
# {'total': 63900000, 'batches': 639, 'time': 2317.9442784786224}
# {'total': 64000000, 'batches': 640, 'time': 2322.5440225601196}
# {'total': 64100000, 'batches': 641, 'time': 2326.622992992401}
# {'total': 64200000, 'batches': 642, 'time': 2330.748037815094}
# {'total': 64300000, 'batches': 643, 'time': 2334.256194591522}
# {'total': 64400000, 'batches': 644, 'time': 2337.8297097682953}
# {'total': 64500000, 'batches': 645, 'time': 2341.310767173767}
# {'total': 64600000, 'batches': 646, 'time': 2344.8050191402435}
# {'total': 64700000, 'batches': 647, 'time': 2348.2948031425476}
# {'total': 64800000, 'batches': 648, 'time': 2351.777396440506}
# {'total': 64900000, 'batches': 649, 'time': 2355.3360941410065}
# {'total': 65000000, 'batches': 650, 'time': 2358.838735818863}
# {'total': 65100000, 'batches': 651, 'time': 2362.3833339214325}
# {'total': 65200000, 'batches': 652, 'time': 2366.0861320495605}
# {'total': 65300000, 'batches': 653, 'time': 2369.560407400131}
# {'total': 65400000, 'batches': 654, 'time': 2373.0182116031647}
# {'total': 65500000, 'batches': 655, 'time': 2376.599682569504}
# {'total': 65600000, 'batches': 656, 'time': 2380.130390405655}
# {'total': 65700000, 'batches': 657, 'time': 2383.607727766037}
# {'total': 65800000, 'batches': 658, 'time': 2387.1182203292847}
# {'total': 65900000, 'batches': 659, 'time': 2390.8838832378387}
# {'total': 66000000, 'batches': 660, 'time': 2394.3415246009827}
# {'total': 66100000, 'batches': 661, 'time': 2397.8131227493286}
# {'total': 66200000, 'batches': 662, 'time': 2401.4125368595123}
# {'total': 66300000, 'batches': 663, 'time': 2405.0105826854706}
# {'total': 66400000, 'batches': 664, 'time': 2408.5870974063873}
# {'total': 66500000, 'batches': 665, 'time': 2412.139680147171}
# {'total': 66600000, 'batches': 666, 'time': 2415.6315157413483}
# {'total': 66700000, 'batches': 667, 'time': 2419.0942821502686}
# {'total': 66800000, 'batches': 668, 'time': 2422.6756715774536}
# {'total': 66900000, 'batches': 669, 'time': 2426.1674704551697}
# {'total': 67000000, 'batches': 670, 'time': 2429.730878829956}
# {'total': 67100000, 'batches': 671, 'time': 2433.217807531357}
# {'total': 67200000, 'batches': 672, 'time': 2436.7707879543304}
# {'total': 67300000, 'batches': 673, 'time': 2440.2786626815796}
# {'total': 67400000, 'batches': 674, 'time': 2443.7772636413574}
# {'total': 67500000, 'batches': 675, 'time': 2447.2580676078796}
# {'total': 67600000, 'batches': 676, 'time': 2450.759640455246}
# {'total': 67700000, 'batches': 677, 'time': 2454.334643602371}
# {'total': 67800000, 'batches': 678, 'time': 2457.811575651169}
# {'total': 67900000, 'batches': 679, 'time': 2461.2759082317352}
# {'total': 68000000, 'batches': 680, 'time': 2464.892543077469}
# {'total': 68100000, 'batches': 681, 'time': 2468.381224632263}
# {'total': 68200000, 'batches': 682, 'time': 2471.899697780609}
# {'total': 68300000, 'batches': 683, 'time': 2475.4047470092773}
# {'total': 68400000, 'batches': 684, 'time': 2479.2691650390625}
# {'total': 68500000, 'batches': 685, 'time': 2482.7717595100403}
# {'total': 68600000, 'batches': 686, 'time': 2486.246456861496}
# {'total': 68700000, 'batches': 687, 'time': 2489.68728351593}
# {'total': 68800000, 'batches': 688, 'time': 2493.318343400955}
# {'total': 68900000, 'batches': 689, 'time': 2496.768538236618}
# {'total': 69000000, 'batches': 690, 'time': 2500.246246814728}
# {'total': 69100000, 'batches': 691, 'time': 2503.728294610977}
# {'total': 69200000, 'batches': 692, 'time': 2507.4955866336823}
# {'total': 69300000, 'batches': 693, 'time': 2510.9990220069885}
# {'total': 69400000, 'batches': 694, 'time': 2514.787652492523}
# {'total': 69500000, 'batches': 695, 'time': 2518.252252101898}
# {'total': 69600000, 'batches': 696, 'time': 2521.702255010605}
# {'total': 69700000, 'batches': 697, 'time': 2525.1743438243866}
# {'total': 69800000, 'batches': 698, 'time': 2528.688630104065}
# {'total': 69900000, 'batches': 699, 'time': 2532.242295026779}
# {'total': 70000000, 'batches': 700, 'time': 2535.7979185581207}
# {'total': 70100000, 'batches': 701, 'time': 2539.305111169815}
# {'total': 70200000, 'batches': 702, 'time': 2542.7920010089874}
# {'total': 70300000, 'batches': 703, 'time': 2546.3012290000916}
# {'total': 70400000, 'batches': 704, 'time': 2549.7611434459686}
# {'total': 70500000, 'batches': 705, 'time': 2553.320536136627}
# {'total': 70600000, 'batches': 706, 'time': 2556.8251452445984}
# {'total': 70700000, 'batches': 707, 'time': 2560.468692302704}
# {'total': 70800000, 'batches': 708, 'time': 2563.950761079788}
# {'total': 70900000, 'batches': 709, 'time': 2567.4728734493256}
# {'total': 71000000, 'batches': 710, 'time': 2570.9618787765503}
# {'total': 71100000, 'batches': 711, 'time': 2574.4416749477386}
# {'total': 71200000, 'batches': 712, 'time': 2577.993928670883}
# {'total': 71300000, 'batches': 713, 'time': 2581.7597320079803}
# {'total': 71400000, 'batches': 714, 'time': 2585.2469370365143}
# {'total': 71500000, 'batches': 715, 'time': 2588.775883436203}
# {'total': 71600000, 'batches': 716, 'time': 2592.2767090797424}
# {'total': 71700000, 'batches': 717, 'time': 2595.7265589237213}
# {'total': 71800000, 'batches': 718, 'time': 2599.249522447586}
# {'total': 71900000, 'batches': 719, 'time': 2602.7187671661377}
# {'total': 72000000, 'batches': 720, 'time': 2606.2359902858734}
# {'total': 72100000, 'batches': 721, 'time': 2609.729662179947}
# {'total': 72200000, 'batches': 722, 'time': 2613.290814638138}
# {'total': 72300000, 'batches': 723, 'time': 2616.803886413574}
# {'total': 72400000, 'batches': 724, 'time': 2620.45393037796}
# {'total': 72500000, 'batches': 725, 'time': 2624.3930892944336}
# {'total': 72600000, 'batches': 726, 'time': 2627.962649822235}
# {'total': 72700000, 'batches': 727, 'time': 2631.4748520851135}
# {'total': 72800000, 'batches': 728, 'time': 2635.0048954486847}
# {'total': 72900000, 'batches': 729, 'time': 2638.555909395218}
# {'total': 73000000, 'batches': 730, 'time': 2642.4403433799744}
# {'total': 73100000, 'batches': 731, 'time': 2645.9587786197662}
# {'total': 73200000, 'batches': 732, 'time': 2649.5585477352142}
# {'total': 73300000, 'batches': 733, 'time': 2653.0667905807495}
# {'total': 73400000, 'batches': 734, 'time': 2656.5653467178345}
# {'total': 73500000, 'batches': 735, 'time': 2660.103048801422}
# {'total': 73600000, 'batches': 736, 'time': 2663.8411099910736}
# {'total': 73700000, 'batches': 737, 'time': 2667.5520117282867}
# {'total': 73800000, 'batches': 738, 'time': 2671.072156906128}
# {'total': 73900000, 'batches': 739, 'time': 2674.6148896217346}
# {'total': 74000000, 'batches': 740, 'time': 2678.269126176834}
# {'total': 74100000, 'batches': 741, 'time': 2681.809091091156}
# {'total': 74200000, 'batches': 742, 'time': 2685.3412623405457}
# {'total': 74300000, 'batches': 743, 'time': 2688.822394132614}
# {'total': 74400000, 'batches': 744, 'time': 2692.648453235626}
# {'total': 74500000, 'batches': 745, 'time': 2696.252610683441}
# {'total': 74600000, 'batches': 746, 'time': 2699.784628868103}
# {'total': 74700000, 'batches': 747, 'time': 2703.3314003944397}
# {'total': 74800000, 'batches': 748, 'time': 2706.85960316658}
# {'total': 74900000, 'batches': 749, 'time': 2710.3469581604004}
# {'total': 75000000, 'batches': 750, 'time': 2714.008413553238}
# {'total': 75100000, 'batches': 751, 'time': 2717.490813732147}
# {'total': 75200000, 'batches': 752, 'time': 2721.066609144211}
# {'total': 75300000, 'batches': 753, 'time': 2724.625039100647}
# {'total': 75400000, 'batches': 754, 'time': 2728.270204782486}
# {'total': 75500000, 'batches': 755, 'time': 2731.7514040470123}
# {'total': 75600000, 'batches': 756, 'time': 2735.3719248771667}
# {'total': 75700000, 'batches': 757, 'time': 2738.8931839466095}
# {'total': 75800000, 'batches': 758, 'time': 2742.6984498500824}
# {'total': 75900000, 'batches': 759, 'time': 2746.207582950592}
# {'total': 76000000, 'batches': 760, 'time': 2749.7125408649445}
# {'total': 76100000, 'batches': 761, 'time': 2753.386000394821}
# {'total': 76200000, 'batches': 762, 'time': 2757.0746426582336}
# {'total': 76300000, 'batches': 763, 'time': 2760.6014297008514}
# {'total': 76400000, 'batches': 764, 'time': 2764.1312923431396}
# {'total': 76500000, 'batches': 765, 'time': 2767.608528614044}
# {'total': 76600000, 'batches': 766, 'time': 2771.0806832313538}
# {'total': 76700000, 'batches': 767, 'time': 2774.5899500846863}
# {'total': 76800000, 'batches': 768, 'time': 2778.141158103943}
# {'total': 76900000, 'batches': 769, 'time': 2781.6931943893433}
# {'total': 77000000, 'batches': 770, 'time': 2785.1600103378296}
# {'total': 77100000, 'batches': 771, 'time': 2788.6443254947662}
# {'total': 77200000, 'batches': 772, 'time': 2792.240674495697}
# {'total': 77300000, 'batches': 773, 'time': 2795.6749415397644}
# {'total': 77400000, 'batches': 774, 'time': 2799.1757414340973}
# {'total': 77500000, 'batches': 775, 'time': 2802.649235725403}
# {'total': 77600000, 'batches': 776, 'time': 2806.272494316101}
# {'total': 77700000, 'batches': 777, 'time': 2809.8708794116974}
# {'total': 77800000, 'batches': 778, 'time': 2813.3419830799103}
# {'total': 77900000, 'batches': 779, 'time': 2816.828380584717}
# {'total': 78000000, 'batches': 780, 'time': 2820.41175031662}
# {'total': 78100000, 'batches': 781, 'time': 2823.913115501404}
# {'total': 78200000, 'batches': 782, 'time': 2827.4145636558533}
# {'total': 78300000, 'batches': 783, 'time': 2830.879865169525}
# {'total': 78400000, 'batches': 784, 'time': 2834.3714735507965}
# {'total': 78500000, 'batches': 785, 'time': 2837.962502717972}
# {'total': 78600000, 'batches': 786, 'time': 2841.445207834244}
# {'total': 78700000, 'batches': 787, 'time': 2844.9579739570618}
# {'total': 78800000, 'batches': 788, 'time': 2848.46436047554}
# {'total': 78900000, 'batches': 789, 'time': 2851.9164187908173}
# {'total': 79000000, 'batches': 790, 'time': 2855.576756000519}
# {'total': 79100000, 'batches': 791, 'time': 2859.206563472748}
# {'total': 79200000, 'batches': 792, 'time': 2862.6750967502594}
# {'total': 79300000, 'batches': 793, 'time': 2866.23259472847}
# {'total': 79400000, 'batches': 794, 'time': 2869.7045669555664}
# {'total': 79500000, 'batches': 795, 'time': 2873.2599589824677}
# {'total': 79600000, 'batches': 796, 'time': 2876.915863275528}
# {'total': 79700000, 'batches': 797, 'time': 2880.8485503196716}
# {'total': 79800000, 'batches': 798, 'time': 2884.3715851306915}
# {'total': 79900000, 'batches': 799, 'time': 2887.8757631778717}
# {'total': 80000000, 'batches': 800, 'time': 2891.4004096984863}
# {'total': 80100000, 'batches': 801, 'time': 2894.940659046173}
# {'total': 80200000, 'batches': 802, 'time': 2898.4310562610626}
# {'total': 80300000, 'batches': 803, 'time': 2902.156359910965}
# {'total': 80400000, 'batches': 804, 'time': 2905.664223432541}
# {'total': 80500000, 'batches': 805, 'time': 2909.249049425125}
# {'total': 80600000, 'batches': 806, 'time': 2912.7236981391907}
# {'total': 80700000, 'batches': 807, 'time': 2916.3879492282867}
# {'total': 80800000, 'batches': 808, 'time': 2919.895294189453}
# {'total': 80900000, 'batches': 809, 'time': 2923.421317577362}
# {'total': 81000000, 'batches': 810, 'time': 2926.9569277763367}
# {'total': 81100000, 'batches': 811, 'time': 2930.4028565883636}
# {'total': 81200000, 'batches': 812, 'time': 2933.9025745391846}
# {'total': 81300000, 'batches': 813, 'time': 2937.4292616844177}
# {'total': 81400000, 'batches': 814, 'time': 2940.8900380134583}
# {'total': 81500000, 'batches': 815, 'time': 2944.8172574043274}
# {'total': 81600000, 'batches': 816, 'time': 2948.3220069408417}
# {'total': 81700000, 'batches': 817, 'time': 2951.8119144439697}
# {'total': 81800000, 'batches': 818, 'time': 2955.4291434288025}
# {'total': 81900000, 'batches': 819, 'time': 2958.982784509659}
# {'total': 82000000, 'batches': 820, 'time': 2962.4242463111877}
# {'total': 82100000, 'batches': 821, 'time': 2966.0286931991577}
# {'total': 82200000, 'batches': 822, 'time': 2969.516284227371}
# {'total': 82300000, 'batches': 823, 'time': 2973.016620874405}
# {'total': 82400000, 'batches': 824, 'time': 2976.5259850025177}
# {'total': 82500000, 'batches': 825, 'time': 2980.040055990219}
# {'total': 82600000, 'batches': 826, 'time': 2983.538048028946}
# {'total': 82700000, 'batches': 827, 'time': 2987.090083360672}
# {'total': 82800000, 'batches': 828, 'time': 2990.579768180847}
# {'total': 82900000, 'batches': 829, 'time': 2994.1489477157593}
# {'total': 83000000, 'batches': 830, 'time': 2997.6629645824432}
# {'total': 83100000, 'batches': 831, 'time': 3001.120324611664}
# {'total': 83200000, 'batches': 832, 'time': 3004.592358827591}
# {'total': 83300000, 'batches': 833, 'time': 3008.1060996055603}
# {'total': 83400000, 'batches': 834, 'time': 3011.552175760269}
# {'total': 83500000, 'batches': 835, 'time': 3015.0376427173615}
# {'total': 83600000, 'batches': 836, 'time': 3018.5472865104675}
# {'total': 83700000, 'batches': 837, 'time': 3022.0064883232117}
# {'total': 83800000, 'batches': 838, 'time': 3025.4436206817627}
# {'total': 83900000, 'batches': 839, 'time': 3028.907372236252}
# {'total': 84000000, 'batches': 840, 'time': 3032.416434288025}
# {'total': 84100000, 'batches': 841, 'time': 3035.8880076408386}
# {'total': 84200000, 'batches': 842, 'time': 3039.3190534114838}
# {'total': 84300000, 'batches': 843, 'time': 3042.790184736252}
# {'total': 84400000, 'batches': 844, 'time': 3046.279867172241}
# {'total': 84500000, 'batches': 845, 'time': 3049.7238385677338}
# {'total': 84600000, 'batches': 846, 'time': 3053.18785238266}
# {'total': 84700000, 'batches': 847, 'time': 3056.622116088867}
# {'total': 84800000, 'batches': 848, 'time': 3060.1435890197754}
# {'total': 84900000, 'batches': 849, 'time': 3063.5928823947906}
# {'total': 85000000, 'batches': 850, 'time': 3067.058360815048}
# {'total': 85100000, 'batches': 851, 'time': 3070.5032818317413}
# {'total': 85200000, 'batches': 852, 'time': 3074.040573835373}
# {'total': 85300000, 'batches': 853, 'time': 3077.512761592865}
# {'total': 85400000, 'batches': 854, 'time': 3080.982032775879}
# {'total': 85500000, 'batches': 855, 'time': 3084.4679806232452}
# {'total': 85600000, 'batches': 856, 'time': 3087.997888803482}
# {'total': 85700000, 'batches': 857, 'time': 3091.4238233566284}
# {'total': 85800000, 'batches': 858, 'time': 3094.8580689430237}
# {'total': 85900000, 'batches': 859, 'time': 3098.3484358787537}
# {'total': 86000000, 'batches': 860, 'time': 3102.087785720825}
# {'total': 86100000, 'batches': 861, 'time': 3105.5808033943176}
# {'total': 86200000, 'batches': 862, 'time': 3109.083587408066}
# {'total': 86300000, 'batches': 863, 'time': 3112.6078412532806}
# {'total': 86400000, 'batches': 864, 'time': 3116.1045372486115}
# {'total': 86500000, 'batches': 865, 'time': 3119.6203384399414}
# {'total': 86600000, 'batches': 866, 'time': 3123.1565222740173}
# {'total': 86700000, 'batches': 867, 'time': 3126.7203891277313}
# {'total': 86800000, 'batches': 868, 'time': 3130.1918437480927}
# {'total': 86900000, 'batches': 869, 'time': 3133.72420334816}
# {'total': 87000000, 'batches': 870, 'time': 3137.238697052002}
# {'total': 87100000, 'batches': 871, 'time': 3140.711700439453}
# {'total': 87143637, 'batches': 872, 'time': 3143.2012157440186}
# CPU times: user 28min 34s, sys: 4.71 s, total: 28min 38s
# Wall time: 52min 23s
# {'total': 87143637, 'batches': 872, 'time': 3143.2012157440186}

# %%
edge_ls = train_df['edge'].unique().tolist()

# %%
for edge in edge_ls:
    #y = train_df['edge'].loc[train_df['edge'] == edge]
    y = train_df[train_df['edge'] == edge]
    #print(y.shape)
    add_edges(y)
# Out:
# []
# {'total': 0, 'batches': 1, 'time': 3.6605336666107178}
# []
# {'total': 0, 'batches': 2, 'time': 7.425798177719116}
# []
# {'total': 0, 'batches': 3, 'time': 11.456313848495483}
# []
# {'total': 0, 'batches': 4, 'time': 12.49168348312378}
# []
# {'total': 0, 'batches': 1, 'time': 3.7426490783691406}
# []
# {'total': 0, 'batches': 2, 'time': 7.435235500335693}
# []
# {'total': 0, 'batches': 3, 'time': 11.047674417495728}
# []
# {'total': 0, 'batches': 4, 'time': 14.634310722351074}
# []
# {'total': 0, 'batches': 5, 'time': 18.22140121459961}
# []
# {'total': 0, 'batches': 6, 'time': 21.741209030151367}
# []
# {'total': 0, 'batches': 7, 'time': 25.36509609222412}
# []
# {'total': 0, 'batches': 8, 'time': 28.782644033432007}
# []
# {'total': 0, 'batches': 9, 'time': 32.36529898643494}
# []
# {'total': 0, 'batches': 10, 'time': 36.06322407722473}
# []
# {'total': 0, 'batches': 11, 'time': 39.536763429641724}
# []
# {'total': 0, 'batches': 12, 'time': 43.06456708908081}
# []
# {'total': 0, 'batches': 13, 'time': 46.43952989578247}
# []
# {'total': 0, 'batches': 14, 'time': 50.05062937736511}
# []
# {'total': 0, 'batches': 15, 'time': 53.42773175239563}
# []
# {'total': 0, 'batches': 16, 'time': 56.98362588882446}
# []
# {'total': 0, 'batches': 17, 'time': 60.530351400375366}
# []
# {'total': 0, 'batches': 18, 'time': 63.985923528671265}
# []
# {'total': 0, 'batches': 19, 'time': 67.52881121635437}
# []
# {'total': 0, 'batches': 20, 'time': 71.33099317550659}
# []
# {'total': 0, 'batches': 21, 'time': 75.26056337356567}
# []
# {'total': 0, 'batches': 22, 'time': 79.06144785881042}
# []
# {'total': 0, 'batches': 23, 'time': 82.90698981285095}
# []
# {'total': 0, 'batches': 24, 'time': 86.38125944137573}
# []
# {'total': 0, 'batches': 25, 'time': 90.22263836860657}
# []
# {'total': 0, 'batches': 26, 'time': 94.06892108917236}
# []
# {'total': 0, 'batches': 27, 'time': 97.88137650489807}
# []
# {'total': 0, 'batches': 28, 'time': 101.65952897071838}
# []
# {'total': 0, 'batches': 29, 'time': 105.57271409034729}
# []
# {'total': 0, 'batches': 30, 'time': 109.48365783691406}
# []
# {'total': 0, 'batches': 31, 'time': 113.24040508270264}
# []
# {'total': 0, 'batches': 32, 'time': 115.01839804649353}
# []
# {'total': 0, 'batches': 1, 'time': 3.334707021713257}
# []
# {'total': 0, 'batches': 1, 'time': 0.19861936569213867}
# []
# {'total': 0, 'batches': 1, 'time': 2.2367703914642334}
# []
# {'total': 0, 'batches': 1, 'time': 3.2894628047943115}
# []
# {'total': 0, 'batches': 2, 'time': 6.741693496704102}
# []
# {'total': 0, 'batches': 3, 'time': 10.151983261108398}
# []
# {'total': 0, 'batches': 4, 'time': 13.613113164901733}
# []
# {'total': 0, 'batches': 5, 'time': 17.068969249725342}
# []
# {'total': 0, 'batches': 6, 'time': 20.508540630340576}
# []
# {'total': 0, 'batches': 7, 'time': 23.926064491271973}
# []
# {'total': 0, 'batches': 8, 'time': 27.213451623916626}
# []
# {'total': 0, 'batches': 9, 'time': 30.599790334701538}
# []
# {'total': 0, 'batches': 10, 'time': 33.98249650001526}
# []
# {'total': 0, 'batches': 11, 'time': 37.68804931640625}
# []
# {'total': 0, 'batches': 12, 'time': 41.28043341636658}
# []
# {'total': 0, 'batches': 13, 'time': 43.27263903617859}
# []
# {'total': 0, 'batches': 1, 'time': 1.2258851528167725}
# []
# {'total': 0, 'batches': 1, 'time': 4.071429252624512}
# []
# {'total': 0, 'batches': 2, 'time': 8.15026068687439}
# []
# {'total': 0, 'batches': 3, 'time': 12.228187084197998}
# []
# {'total': 0, 'batches': 4, 'time': 16.49183177947998}
# []
# {'total': 0, 'batches': 5, 'time': 20.980706453323364}
# []
# {'total': 0, 'batches': 6, 'time': 25.45276188850403}
# []
# {'total': 0, 'batches': 7, 'time': 30.195743322372437}
# []
# {'total': 0, 'batches': 8, 'time': 35.18462681770325}
# []
# {'total': 0, 'batches': 9, 'time': 39.97064781188965}
# []
# {'total': 0, 'batches': 10, 'time': 44.66144895553589}
# []
# {'total': 0, 'batches': 11, 'time': 46.12954783439636}
# []
# {'total': 0, 'batches': 1, 'time': 1.6164343357086182}
# []
# {'total': 0, 'batches': 1, 'time': 0.6631109714508057}
# []
# {'total': 0, 'batches': 1, 'time': 0.38117074966430664}
# []
# {'total': 0, 'batches': 1, 'time': 3.519791841506958}
# []
# {'total': 0, 'batches': 2, 'time': 6.9284162521362305}
# []
# {'total': 0, 'batches': 3, 'time': 10.222337007522583}
# []
# {'total': 0, 'batches': 4, 'time': 13.526323318481445}
# []
# {'total': 0, 'batches': 5, 'time': 16.885294675827026}
# []
# {'total': 0, 'batches': 6, 'time': 20.321972608566284}
# []
# {'total': 0, 'batches': 7, 'time': 23.654587507247925}
# []
# {'total': 0, 'batches': 8, 'time': 27.010860443115234}
# []
# {'total': 0, 'batches': 9, 'time': 30.31722068786621}
# []
# {'total': 0, 'batches': 10, 'time': 33.67581510543823}
# []
# {'total': 0, 'batches': 11, 'time': 36.969239711761475}
# []
# {'total': 0, 'batches': 12, 'time': 40.29265880584717}
# []
# {'total': 0, 'batches': 13, 'time': 43.59428429603577}
# []
# {'total': 0, 'batches': 14, 'time': 46.84446477890015}
# []
# {'total': 0, 'batches': 15, 'time': 50.18283438682556}
# []
# {'total': 0, 'batches': 16, 'time': 53.618069887161255}
# []
# {'total': 0, 'batches': 17, 'time': 57.104225397109985}
# []
# {'total': 0, 'batches': 18, 'time': 60.47177481651306}
# []
# {'total': 0, 'batches': 19, 'time': 63.83980655670166}
# []
# {'total': 0, 'batches': 20, 'time': 67.23213195800781}
# []
# {'total': 0, 'batches': 21, 'time': 70.59326124191284}
# []
# {'total': 0, 'batches': 22, 'time': 73.91584062576294}
# []
# {'total': 0, 'batches': 23, 'time': 77.27514266967773}
# []
# {'total': 0, 'batches': 24, 'time': 80.6142954826355}
# []
# {'total': 0, 'batches': 25, 'time': 84.10247325897217}
# []
# {'total': 0, 'batches': 26, 'time': 87.57658648490906}
# []
# {'total': 0, 'batches': 27, 'time': 91.05316591262817}
# []
# {'total': 0, 'batches': 28, 'time': 94.53238654136658}
# []
# {'total': 0, 'batches': 29, 'time': 98.04333591461182}
# []
# {'total': 0, 'batches': 30, 'time': 101.38929224014282}
# []
# {'total': 0, 'batches': 31, 'time': 104.77527356147766}
# []
# {'total': 0, 'batches': 32, 'time': 108.15332221984863}
# []
# {'total': 0, 'batches': 33, 'time': 111.49426579475403}
# []
# {'total': 0, 'batches': 34, 'time': 114.8631579875946}
# []
# {'total': 0, 'batches': 35, 'time': 118.18946123123169}
# []
# {'total': 0, 'batches': 36, 'time': 121.556312084198}
# []
# {'total': 0, 'batches': 37, 'time': 125.01499032974243}
# []
# {'total': 0, 'batches': 38, 'time': 128.32328462600708}
# []
# {'total': 0, 'batches': 39, 'time': 131.58092546463013}
# []
# {'total': 0, 'batches': 40, 'time': 134.84495615959167}
# []
# {'total': 0, 'batches': 41, 'time': 138.230806350708}
# []
# {'total': 0, 'batches': 42, 'time': 141.57110691070557}
# []
# {'total': 0, 'batches': 43, 'time': 144.93786025047302}
# []
# {'total': 0, 'batches': 44, 'time': 148.32119488716125}
# []
# {'total': 0, 'batches': 45, 'time': 151.71102952957153}
# []
# {'total': 0, 'batches': 46, 'time': 155.04768776893616}
# []
# {'total': 0, 'batches': 47, 'time': 158.74709701538086}
# []
# {'total': 0, 'batches': 48, 'time': 162.29741549491882}
# []
# {'total': 0, 'batches': 49, 'time': 165.63065457344055}
# []
# {'total': 0, 'batches': 50, 'time': 168.98178267478943}
# []
# {'total': 0, 'batches': 51, 'time': 172.3261272907257}
# []
# {'total': 0, 'batches': 52, 'time': 175.6260781288147}
# []
# {'total': 0, 'batches': 53, 'time': 178.947984457016}
# []
# {'total': 0, 'batches': 54, 'time': 182.28100848197937}
# []
# {'total': 0, 'batches': 55, 'time': 185.57063102722168}
# []
# {'total': 0, 'batches': 56, 'time': 188.84739804267883}
# []
# {'total': 0, 'batches': 57, 'time': 192.28998947143555}
# []
# {'total': 0, 'batches': 58, 'time': 195.58487057685852}
# []
# {'total': 0, 'batches': 59, 'time': 198.87656044960022}
# []
# {'total': 0, 'batches': 60, 'time': 202.21000742912292}
# []
# {'total': 0, 'batches': 61, 'time': 205.49732208251953}
# []
# {'total': 0, 'batches': 62, 'time': 208.7459261417389}
# []
# {'total': 0, 'batches': 63, 'time': 212.00262928009033}
# []
# {'total': 0, 'batches': 64, 'time': 215.28239369392395}
# []
# {'total': 0, 'batches': 65, 'time': 218.58009791374207}
# []
# {'total': 0, 'batches': 66, 'time': 221.80614733695984}
# []
# {'total': 0, 'batches': 67, 'time': 225.07047581672668}
# []
# {'total': 0, 'batches': 68, 'time': 228.32506442070007}
# []
# {'total': 0, 'batches': 69, 'time': 231.59002041816711}
# []
# {'total': 0, 'batches': 70, 'time': 234.93247270584106}
# []
# {'total': 0, 'batches': 71, 'time': 238.23295402526855}
# []
# {'total': 0, 'batches': 72, 'time': 241.57595348358154}
# []
# {'total': 0, 'batches': 73, 'time': 244.8556890487671}
# []
# {'total': 0, 'batches': 74, 'time': 248.18551921844482}
# []
# {'total': 0, 'batches': 75, 'time': 251.5234124660492}
# []
# {'total': 0, 'batches': 76, 'time': 254.78996467590332}
# []
# {'total': 0, 'batches': 77, 'time': 258.1078119277954}
# []
# {'total': 0, 'batches': 78, 'time': 261.55561661720276}
# []
# {'total': 0, 'batches': 79, 'time': 264.93678307533264}
# []
# {'total': 0, 'batches': 80, 'time': 268.30030131340027}
# []
# {'total': 0, 'batches': 81, 'time': 271.61932611465454}
# []
# {'total': 0, 'batches': 82, 'time': 274.8928174972534}
# []
# {'total': 0, 'batches': 83, 'time': 278.2156889438629}
# []
# {'total': 0, 'batches': 84, 'time': 281.4501645565033}
# []
# {'total': 0, 'batches': 85, 'time': 284.77873063087463}
# []
# {'total': 0, 'batches': 86, 'time': 288.1280233860016}
# []
# {'total': 0, 'batches': 87, 'time': 291.4220006465912}
# []
# {'total': 0, 'batches': 88, 'time': 294.83113837242126}
# []
# {'total': 0, 'batches': 89, 'time': 298.2038242816925}
# []
# {'total': 0, 'batches': 90, 'time': 301.5240273475647}
# []
# {'total': 0, 'batches': 91, 'time': 304.8554630279541}
# []
# {'total': 0, 'batches': 92, 'time': 308.2170102596283}
# []
# {'total': 0, 'batches': 93, 'time': 311.481320142746}
# []
# {'total': 0, 'batches': 94, 'time': 314.7766115665436}
# []
# {'total': 0, 'batches': 95, 'time': 318.08287024497986}
# []
# {'total': 0, 'batches': 96, 'time': 321.4129412174225}
# []
# {'total': 0, 'batches': 97, 'time': 324.7262170314789}
# []
# {'total': 0, 'batches': 98, 'time': 328.0388283729553}
# []
# {'total': 0, 'batches': 99, 'time': 331.4426338672638}
# []
# {'total': 0, 'batches': 100, 'time': 334.80188179016113}
# []
# {'total': 0, 'batches': 101, 'time': 338.19205832481384}
# []
# {'total': 0, 'batches': 102, 'time': 341.56661319732666}
# []
# {'total': 0, 'batches': 103, 'time': 344.932669878006}
# []
# {'total': 0, 'batches': 104, 'time': 348.2815318107605}
# []
# {'total': 0, 'batches': 105, 'time': 351.68210220336914}
# []
# {'total': 0, 'batches': 106, 'time': 355.03839921951294}
# []
# {'total': 0, 'batches': 107, 'time': 358.4178032875061}
# []
# {'total': 0, 'batches': 108, 'time': 362.07882261276245}
# []
# {'total': 0, 'batches': 109, 'time': 365.4819266796112}
# []
# {'total': 0, 'batches': 110, 'time': 368.8218686580658}
# []
# {'total': 0, 'batches': 111, 'time': 372.19232416152954}
# []
# {'total': 0, 'batches': 112, 'time': 375.5846252441406}
# []
# {'total': 0, 'batches': 113, 'time': 378.99680614471436}
# []
# {'total': 0, 'batches': 114, 'time': 382.3338851928711}
# []
# {'total': 0, 'batches': 115, 'time': 385.7377462387085}
# []
# {'total': 0, 'batches': 116, 'time': 389.13160848617554}
# []
# {'total': 0, 'batches': 117, 'time': 392.7763087749481}
# []
# {'total': 0, 'batches': 118, 'time': 396.23631167411804}
# []
# {'total': 0, 'batches': 119, 'time': 399.6433107852936}
# []
# {'total': 0, 'batches': 120, 'time': 402.9804756641388}
# []
# {'total': 0, 'batches': 121, 'time': 406.35532784461975}
# []
# {'total': 0, 'batches': 122, 'time': 409.7257523536682}
# []
# {'total': 0, 'batches': 123, 'time': 413.14105343818665}
# []
# {'total': 0, 'batches': 124, 'time': 416.48848128318787}
# []
# {'total': 0, 'batches': 125, 'time': 419.83102345466614}
# []
# {'total': 0, 'batches': 126, 'time': 423.3794071674347}
# []
# {'total': 0, 'batches': 127, 'time': 426.9696378707886}
# []
# {'total': 0, 'batches': 128, 'time': 430.30763697624207}
# []
# {'total': 0, 'batches': 129, 'time': 433.66744899749756}
# []
# {'total': 0, 'batches': 130, 'time': 436.9755675792694}
# []
# {'total': 0, 'batches': 131, 'time': 440.31187891960144}
# []
# {'total': 0, 'batches': 132, 'time': 443.6320948600769}
# []
# {'total': 0, 'batches': 133, 'time': 446.9555232524872}
# []
# {'total': 0, 'batches': 134, 'time': 450.30099725723267}
# []
# {'total': 0, 'batches': 135, 'time': 453.6601688861847}
# []
# {'total': 0, 'batches': 136, 'time': 457.1222405433655}
# []
# {'total': 0, 'batches': 137, 'time': 460.4420175552368}
# []
# {'total': 0, 'batches': 138, 'time': 463.81950783729553}
# []
# {'total': 0, 'batches': 139, 'time': 467.2200050354004}
# []
# {'total': 0, 'batches': 140, 'time': 470.55758357048035}
# []
# {'total': 0, 'batches': 141, 'time': 473.8414378166199}
# []
# {'total': 0, 'batches': 142, 'time': 477.19377732276917}
# []
# {'total': 0, 'batches': 143, 'time': 480.55848360061646}
# []
# {'total': 0, 'batches': 144, 'time': 483.91751980781555}
# []
# {'total': 0, 'batches': 145, 'time': 487.2400848865509}
# []
# {'total': 0, 'batches': 146, 'time': 490.8067457675934}
# []
# {'total': 0, 'batches': 147, 'time': 494.17985010147095}
# []
# {'total': 0, 'batches': 148, 'time': 497.580025434494}
# []
# {'total': 0, 'batches': 149, 'time': 501.00011229515076}
# []
# {'total': 0, 'batches': 150, 'time': 504.4071981906891}
# []
# {'total': 0, 'batches': 151, 'time': 507.68208146095276}
# []
# {'total': 0, 'batches': 152, 'time': 511.0080146789551}
# []
# {'total': 0, 'batches': 153, 'time': 514.3801882266998}
# []
# {'total': 0, 'batches': 154, 'time': 517.6471078395844}
# []
# {'total': 0, 'batches': 155, 'time': 520.9612507820129}
# []
# {'total': 0, 'batches': 156, 'time': 524.4021093845367}
# []
# {'total': 0, 'batches': 157, 'time': 527.7648551464081}
# []
# {'total': 0, 'batches': 158, 'time': 531.1140749454498}
# []
# {'total': 0, 'batches': 159, 'time': 534.4497964382172}
# []
# {'total': 0, 'batches': 160, 'time': 537.8587157726288}
# []
# {'total': 0, 'batches': 161, 'time': 541.2524960041046}
# []
# {'total': 0, 'batches': 162, 'time': 544.6273074150085}
# []
# {'total': 0, 'batches': 163, 'time': 547.9834790229797}
# []
# {'total': 0, 'batches': 164, 'time': 551.3417873382568}
# []
# {'total': 0, 'batches': 165, 'time': 554.8023216724396}
# []
# {'total': 0, 'batches': 166, 'time': 558.464638710022}
# []
# {'total': 0, 'batches': 167, 'time': 561.7945053577423}
# []
# {'total': 0, 'batches': 168, 'time': 565.2155742645264}
# []
# {'total': 0, 'batches': 169, 'time': 568.6735587120056}
# []
# {'total': 0, 'batches': 170, 'time': 572.0863499641418}
# []
# {'total': 0, 'batches': 171, 'time': 575.4800670146942}
# []
# {'total': 0, 'batches': 172, 'time': 578.8878948688507}
# []
# {'total': 0, 'batches': 173, 'time': 582.3525125980377}
# []
# {'total': 0, 'batches': 174, 'time': 585.6771774291992}
# []
# {'total': 0, 'batches': 175, 'time': 589.0761289596558}
# []
# {'total': 0, 'batches': 176, 'time': 592.599440574646}
# []
# {'total': 0, 'batches': 177, 'time': 595.9361388683319}
# []
# {'total': 0, 'batches': 178, 'time': 599.216735124588}
# []
# {'total': 0, 'batches': 179, 'time': 602.5092287063599}
# []
# {'total': 0, 'batches': 180, 'time': 605.8688287734985}
# []
# {'total': 0, 'batches': 181, 'time': 609.2711455821991}
# []
# {'total': 0, 'batches': 182, 'time': 612.6171722412109}
# []
# {'total': 0, 'batches': 183, 'time': 616.0291006565094}
# []
# {'total': 0, 'batches': 184, 'time': 619.4370446205139}
# []
# {'total': 0, 'batches': 185, 'time': 622.8718798160553}
# []
# {'total': 0, 'batches': 186, 'time': 626.3628642559052}
# []
# {'total': 0, 'batches': 187, 'time': 629.8175835609436}
# []
# {'total': 0, 'batches': 188, 'time': 633.3408193588257}
# []
# {'total': 0, 'batches': 189, 'time': 636.7743942737579}
# []
# {'total': 0, 'batches': 190, 'time': 640.3210473060608}
# []
# {'total': 0, 'batches': 191, 'time': 643.8621065616608}
# []
# {'total': 0, 'batches': 192, 'time': 647.4033665657043}
# []
# {'total': 0, 'batches': 193, 'time': 650.8932251930237}
# []
# {'total': 0, 'batches': 194, 'time': 654.300728559494}
# []
# {'total': 0, 'batches': 195, 'time': 657.7830486297607}
# []
# {'total': 0, 'batches': 196, 'time': 661.1563158035278}
# []
# {'total': 0, 'batches': 197, 'time': 664.5236306190491}
# []
# {'total': 0, 'batches': 198, 'time': 667.9100768566132}
# []
# {'total': 0, 'batches': 199, 'time': 671.3317906856537}
# []
# {'total': 0, 'batches': 200, 'time': 674.7465617656708}
# []
# {'total': 0, 'batches': 201, 'time': 678.1331269741058}
# []
# {'total': 0, 'batches': 202, 'time': 681.5279729366302}
# []
# {'total': 0, 'batches': 203, 'time': 684.9689209461212}
# []
# {'total': 0, 'batches': 204, 'time': 688.2973446846008}
# []
# {'total': 0, 'batches': 205, 'time': 691.64994597435}
# []
# {'total': 0, 'batches': 206, 'time': 695.0543041229248}
# []
# {'total': 0, 'batches': 207, 'time': 698.39519739151}
# []
# {'total': 0, 'batches': 208, 'time': 701.7519431114197}
# []
# {'total': 0, 'batches': 209, 'time': 705.1686606407166}
# []
# {'total': 0, 'batches': 210, 'time': 708.5279359817505}
# []
# {'total': 0, 'batches': 211, 'time': 711.9070191383362}
# []
# {'total': 0, 'batches': 212, 'time': 715.2680985927582}
# []
# {'total': 0, 'batches': 213, 'time': 718.5591976642609}
# []
# {'total': 0, 'batches': 214, 'time': 722.057505607605}
# []
# {'total': 0, 'batches': 215, 'time': 725.5515217781067}
# []
# {'total': 0, 'batches': 216, 'time': 729.0568430423737}
# []
# {'total': 0, 'batches': 217, 'time': 732.5344369411469}
# []
# {'total': 0, 'batches': 218, 'time': 735.9639718532562}
# []
# {'total': 0, 'batches': 219, 'time': 739.4072165489197}
# []
# {'total': 0, 'batches': 220, 'time': 742.8717670440674}
# []
# {'total': 0, 'batches': 221, 'time': 746.3130671977997}
# []
# {'total': 0, 'batches': 222, 'time': 749.7486412525177}
# []
# {'total': 0, 'batches': 223, 'time': 753.2575891017914}
# []
# {'total': 0, 'batches': 224, 'time': 756.6373269557953}
# []
# {'total': 0, 'batches': 225, 'time': 759.9435799121857}
# []
# {'total': 0, 'batches': 226, 'time': 763.2063615322113}
# []
# {'total': 0, 'batches': 227, 'time': 766.5608077049255}
# []
# {'total': 0, 'batches': 228, 'time': 769.9425401687622}
# []
# {'total': 0, 'batches': 229, 'time': 773.3288164138794}
# []
# {'total': 0, 'batches': 230, 'time': 776.7085075378418}
# []
# {'total': 0, 'batches': 231, 'time': 780.003201007843}
# []
# {'total': 0, 'batches': 232, 'time': 783.2969896793365}
# []
# {'total': 0, 'batches': 233, 'time': 786.6230247020721}
# []
# {'total': 0, 'batches': 234, 'time': 789.9657270908356}
# []
# {'total': 0, 'batches': 235, 'time': 793.3233304023743}
# []
# {'total': 0, 'batches': 236, 'time': 796.7291412353516}
# []
# {'total': 0, 'batches': 237, 'time': 800.0744152069092}
# []
# {'total': 0, 'batches': 238, 'time': 803.4564161300659}
# []
# {'total': 0, 'batches': 239, 'time': 806.9077446460724}
# []
# {'total': 0, 'batches': 240, 'time': 810.3251464366913}
# []
# {'total': 0, 'batches': 241, 'time': 813.7639648914337}
# []
# {'total': 0, 'batches': 242, 'time': 817.1706531047821}
# []
# {'total': 0, 'batches': 243, 'time': 820.5426411628723}
# []
# {'total': 0, 'batches': 244, 'time': 823.8701639175415}
# []
# {'total': 0, 'batches': 245, 'time': 827.2441840171814}
# []
# {'total': 0, 'batches': 246, 'time': 830.5638213157654}
# []
# {'total': 0, 'batches': 247, 'time': 833.87966132164}
# []
# {'total': 0, 'batches': 248, 'time': 837.2390818595886}
# []
# {'total': 0, 'batches': 249, 'time': 840.7060377597809}
# []
# {'total': 0, 'batches': 250, 'time': 844.0701949596405}
# []
# {'total': 0, 'batches': 251, 'time': 847.474235534668}
# []
# {'total': 0, 'batches': 252, 'time': 850.9113564491272}
# []
# {'total': 0, 'batches': 253, 'time': 854.2222731113434}
# []
# {'total': 0, 'batches': 254, 'time': 857.5125231742859}
# []
# {'total': 0, 'batches': 255, 'time': 860.8617248535156}
# []
# {'total': 0, 'batches': 256, 'time': 864.180477142334}
# []
# {'total': 0, 'batches': 257, 'time': 867.4887421131134}
# []
# {'total': 0, 'batches': 258, 'time': 870.7458071708679}
# []
# {'total': 0, 'batches': 259, 'time': 874.0492315292358}
# []
# {'total': 0, 'batches': 260, 'time': 877.2990851402283}
# []
# {'total': 0, 'batches': 261, 'time': 880.6247146129608}
# []
# {'total': 0, 'batches': 262, 'time': 883.9331109523773}
# []
# {'total': 0, 'batches': 263, 'time': 887.217563867569}
# []
# {'total': 0, 'batches': 264, 'time': 890.5711023807526}
# []
# {'total': 0, 'batches': 265, 'time': 893.8661201000214}
# []
# {'total': 0, 'batches': 266, 'time': 897.1526737213135}
# []
# {'total': 0, 'batches': 267, 'time': 900.4516937732697}
# []
# {'total': 0, 'batches': 268, 'time': 903.7808818817139}
# []
# {'total': 0, 'batches': 269, 'time': 907.1833508014679}
# []
# {'total': 0, 'batches': 270, 'time': 910.5522820949554}
# []
# {'total': 0, 'batches': 271, 'time': 913.8847880363464}
# []
# {'total': 0, 'batches': 272, 'time': 917.1974575519562}
# []
# {'total': 0, 'batches': 273, 'time': 920.4874536991119}
# []
# {'total': 0, 'batches': 274, 'time': 923.8217823505402}
# []
# {'total': 0, 'batches': 275, 'time': 927.1505672931671}
# []
# {'total': 0, 'batches': 276, 'time': 930.4345381259918}
# []
# {'total': 0, 'batches': 277, 'time': 933.8256692886353}
# []
# {'total': 0, 'batches': 278, 'time': 937.1470007896423}
# []
# {'total': 0, 'batches': 279, 'time': 940.5270059108734}
# []
# {'total': 0, 'batches': 280, 'time': 943.899786233902}
# []
# {'total': 0, 'batches': 281, 'time': 947.1829960346222}
# []
# {'total': 0, 'batches': 282, 'time': 950.4348549842834}
# []
# {'total': 0, 'batches': 283, 'time': 953.7338228225708}
# []
# {'total': 0, 'batches': 284, 'time': 957.014928817749}
# []
# {'total': 0, 'batches': 285, 'time': 960.3169295787811}
# []
# {'total': 0, 'batches': 286, 'time': 963.584109544754}
# []
# {'total': 0, 'batches': 287, 'time': 966.886518239975}
# []
# {'total': 0, 'batches': 288, 'time': 970.1635556221008}
# []
# {'total': 0, 'batches': 289, 'time': 973.4814615249634}
# []
# {'total': 0, 'batches': 290, 'time': 976.8658106327057}
# []
# {'total': 0, 'batches': 291, 'time': 980.2132978439331}
# []
# {'total': 0, 'batches': 292, 'time': 983.5633065700531}
# []
# {'total': 0, 'batches': 293, 'time': 986.8453471660614}
# []
# {'total': 0, 'batches': 294, 'time': 990.2058053016663}
# []
# {'total': 0, 'batches': 295, 'time': 993.5604848861694}
# []
# {'total': 0, 'batches': 296, 'time': 996.9181454181671}
# []
# {'total': 0, 'batches': 297, 'time': 1000.2274370193481}
# []
# {'total': 0, 'batches': 298, 'time': 1003.5470054149628}
# []
# {'total': 0, 'batches': 299, 'time': 1006.8234486579895}
# []
# {'total': 0, 'batches': 300, 'time': 1010.1313767433167}
# []
# {'total': 0, 'batches': 301, 'time': 1013.4359982013702}
# []
# {'total': 0, 'batches': 302, 'time': 1016.748393535614}
# []
# {'total': 0, 'batches': 303, 'time': 1020.0739488601685}
# []
# {'total': 0, 'batches': 304, 'time': 1023.3963997364044}
# []
# {'total': 0, 'batches': 305, 'time': 1026.7836401462555}
# []
# {'total': 0, 'batches': 306, 'time': 1030.1376729011536}
# []
# {'total': 0, 'batches': 307, 'time': 1033.4404454231262}
# []
# {'total': 0, 'batches': 308, 'time': 1036.782300710678}
# []
# {'total': 0, 'batches': 309, 'time': 1040.143147945404}
# []
# {'total': 0, 'batches': 310, 'time': 1043.5061383247375}
# []
# {'total': 0, 'batches': 311, 'time': 1046.9340512752533}
# []
# {'total': 0, 'batches': 312, 'time': 1050.2661499977112}
# []
# {'total': 0, 'batches': 313, 'time': 1053.7956087589264}
# []
# {'total': 0, 'batches': 314, 'time': 1057.1461262702942}
# []
# {'total': 0, 'batches': 315, 'time': 1060.558175086975}
# []
# {'total': 0, 'batches': 316, 'time': 1063.8304080963135}
# []
# {'total': 0, 'batches': 317, 'time': 1067.1996431350708}
# []
# {'total': 0, 'batches': 318, 'time': 1070.5228950977325}
# []
# {'total': 0, 'batches': 319, 'time': 1073.876975774765}
# []
# {'total': 0, 'batches': 320, 'time': 1077.17809176445}
# []
# {'total': 0, 'batches': 321, 'time': 1080.5630190372467}
# []
# {'total': 0, 'batches': 322, 'time': 1083.9605510234833}
# []
# {'total': 0, 'batches': 323, 'time': 1087.371691942215}
# []
# {'total': 0, 'batches': 324, 'time': 1090.767704486847}
# []
# {'total': 0, 'batches': 325, 'time': 1094.173457145691}
# []
# {'total': 0, 'batches': 326, 'time': 1097.4697136878967}
# []
# {'total': 0, 'batches': 327, 'time': 1100.841468334198}
# []
# {'total': 0, 'batches': 328, 'time': 1104.1985776424408}
# []
# {'total': 0, 'batches': 329, 'time': 1107.4742107391357}
# []
# {'total': 0, 'batches': 330, 'time': 1110.7549629211426}
# []
# {'total': 0, 'batches': 331, 'time': 1114.0594696998596}
# []
# {'total': 0, 'batches': 332, 'time': 1117.3607816696167}
# []
# {'total': 0, 'batches': 333, 'time': 1120.7749934196472}
# []
# {'total': 0, 'batches': 334, 'time': 1124.08260846138}
# []
# {'total': 0, 'batches': 335, 'time': 1127.4282240867615}
# []
# {'total': 0, 'batches': 336, 'time': 1130.7357470989227}
# []
# {'total': 0, 'batches': 337, 'time': 1134.1050136089325}
# []
# {'total': 0, 'batches': 338, 'time': 1137.4718890190125}
# []
# {'total': 0, 'batches': 339, 'time': 1140.7896270751953}
# []
# {'total': 0, 'batches': 340, 'time': 1144.151870250702}
# []
# {'total': 0, 'batches': 341, 'time': 1147.4558532238007}
# []
# {'total': 0, 'batches': 342, 'time': 1150.8034074306488}
# []
# {'total': 0, 'batches': 343, 'time': 1154.4502804279327}
# []
# {'total': 0, 'batches': 344, 'time': 1157.9944956302643}
# []
# {'total': 0, 'batches': 345, 'time': 1161.3247616291046}
# []
# {'total': 0, 'batches': 346, 'time': 1164.6934566497803}
# []
# {'total': 0, 'batches': 347, 'time': 1168.1520981788635}
# []
# {'total': 0, 'batches': 348, 'time': 1171.5464851856232}
# []
# {'total': 0, 'batches': 349, 'time': 1174.9306712150574}
# []
# {'total': 0, 'batches': 350, 'time': 1178.3599255084991}
# []
# {'total': 0, 'batches': 351, 'time': 1181.6963231563568}
# []
# {'total': 0, 'batches': 352, 'time': 1184.9946823120117}
# []
# {'total': 0, 'batches': 353, 'time': 1188.5171535015106}
# []
# {'total': 0, 'batches': 354, 'time': 1191.9085597991943}
# []
# {'total': 0, 'batches': 355, 'time': 1195.3461174964905}
# []
# {'total': 0, 'batches': 356, 'time': 1198.6883277893066}
# []
# {'total': 0, 'batches': 357, 'time': 1201.9971313476562}
# []
# {'total': 0, 'batches': 358, 'time': 1205.3198018074036}
# []
# {'total': 0, 'batches': 359, 'time': 1208.6785793304443}
# []
# {'total': 0, 'batches': 360, 'time': 1212.1202836036682}
# []
# {'total': 0, 'batches': 361, 'time': 1215.5546128749847}
# []
# {'total': 0, 'batches': 362, 'time': 1218.9473962783813}
# []
# {'total': 0, 'batches': 363, 'time': 1222.4477746486664}
# []
# {'total': 0, 'batches': 364, 'time': 1225.8240139484406}
# []
# {'total': 0, 'batches': 365, 'time': 1229.1479172706604}
# []
# {'total': 0, 'batches': 366, 'time': 1232.5489180088043}
# []
# {'total': 0, 'batches': 367, 'time': 1235.8626413345337}
# []
# {'total': 0, 'batches': 368, 'time': 1239.2308373451233}
# []
# {'total': 0, 'batches': 369, 'time': 1242.5373044013977}
# []
# {'total': 0, 'batches': 370, 'time': 1245.9110040664673}
# []
# {'total': 0, 'batches': 371, 'time': 1249.28431558609}
# []
# {'total': 0, 'batches': 372, 'time': 1252.7856628894806}
# []
# {'total': 0, 'batches': 373, 'time': 1256.2580835819244}
# []
# {'total': 0, 'batches': 374, 'time': 1259.5935771465302}
# []
# {'total': 0, 'batches': 375, 'time': 1263.0315330028534}
# []
# {'total': 0, 'batches': 376, 'time': 1266.4332690238953}
# []
# {'total': 0, 'batches': 377, 'time': 1269.8172855377197}
# []
# {'total': 0, 'batches': 378, 'time': 1273.1517300605774}
# []
# {'total': 0, 'batches': 379, 'time': 1276.4295098781586}
# []
# {'total': 0, 'batches': 380, 'time': 1279.783923149109}
# []
# {'total': 0, 'batches': 381, 'time': 1283.0930275917053}
# []
# {'total': 0, 'batches': 382, 'time': 1286.5485746860504}
# []
# {'total': 0, 'batches': 383, 'time': 1289.8764805793762}
# []
# {'total': 0, 'batches': 384, 'time': 1293.2020497322083}
# []
# {'total': 0, 'batches': 385, 'time': 1296.4632184505463}
# []
# {'total': 0, 'batches': 386, 'time': 1299.8089790344238}
# []
# {'total': 0, 'batches': 387, 'time': 1303.1240236759186}
# []
# {'total': 0, 'batches': 388, 'time': 1306.504754781723}
# []
# {'total': 0, 'batches': 389, 'time': 1309.8477840423584}
# []
# {'total': 0, 'batches': 390, 'time': 1313.162436723709}
# []
# {'total': 0, 'batches': 391, 'time': 1316.4491167068481}
# []
# {'total': 0, 'batches': 392, 'time': 1319.8297998905182}
# []
# {'total': 0, 'batches': 393, 'time': 1323.165843963623}
# []
# {'total': 0, 'batches': 394, 'time': 1326.4422070980072}
# []
# {'total': 0, 'batches': 395, 'time': 1329.7107269763947}
# []
# {'total': 0, 'batches': 396, 'time': 1333.054752111435}
# []
# {'total': 0, 'batches': 397, 'time': 1336.3248045444489}
# []
# {'total': 0, 'batches': 398, 'time': 1339.7234749794006}
# []
# {'total': 0, 'batches': 399, 'time': 1343.0166275501251}
# []
# {'total': 0, 'batches': 400, 'time': 1346.3779323101044}
# []
# {'total': 0, 'batches': 401, 'time': 1349.6711521148682}
# []
# {'total': 0, 'batches': 402, 'time': 1353.1275029182434}
# []
# {'total': 0, 'batches': 403, 'time': 1356.5379104614258}
# []
# {'total': 0, 'batches': 404, 'time': 1359.8589916229248}
# []
# {'total': 0, 'batches': 405, 'time': 1363.2007687091827}
# []
# {'total': 0, 'batches': 406, 'time': 1366.495318889618}
# []
# {'total': 0, 'batches': 407, 'time': 1369.8388006687164}
# []
# {'total': 0, 'batches': 408, 'time': 1373.151844739914}
# []
# {'total': 0, 'batches': 409, 'time': 1376.5657696723938}
# []
# {'total': 0, 'batches': 410, 'time': 1379.836778640747}
# []
# {'total': 0, 'batches': 411, 'time': 1383.120153427124}
# []
# {'total': 0, 'batches': 412, 'time': 1386.6645815372467}
# []
# {'total': 0, 'batches': 413, 'time': 1389.977355003357}
# []
# {'total': 0, 'batches': 414, 'time': 1393.3304619789124}
# []
# {'total': 0, 'batches': 415, 'time': 1396.6925163269043}
# []
# {'total': 0, 'batches': 416, 'time': 1400.0317826271057}
# []
# {'total': 0, 'batches': 417, 'time': 1403.328548192978}
# []
# {'total': 0, 'batches': 418, 'time': 1406.6544277668}
# []
# {'total': 0, 'batches': 419, 'time': 1410.00852060318}
# []
# {'total': 0, 'batches': 420, 'time': 1413.358201265335}
# []
# {'total': 0, 'batches': 421, 'time': 1416.8043434619904}
# []
# {'total': 0, 'batches': 422, 'time': 1420.276948928833}
# []
# {'total': 0, 'batches': 423, 'time': 1423.6004431247711}
# []
# {'total': 0, 'batches': 424, 'time': 1426.9086871147156}
# []
# {'total': 0, 'batches': 425, 'time': 1430.14830493927}
# []
# {'total': 0, 'batches': 426, 'time': 1433.4395718574524}
# []
# {'total': 0, 'batches': 427, 'time': 1436.7148518562317}
# []
# {'total': 0, 'batches': 428, 'time': 1439.9939422607422}
# []
# {'total': 0, 'batches': 429, 'time': 1443.3012006282806}
# []
# {'total': 0, 'batches': 430, 'time': 1446.64342045784}
# []
# {'total': 0, 'batches': 431, 'time': 1450.1463108062744}
# []
# {'total': 0, 'batches': 432, 'time': 1453.535197019577}
# []
# {'total': 0, 'batches': 433, 'time': 1456.8044579029083}
# []
# {'total': 0, 'batches': 434, 'time': 1460.1440875530243}
# []
# {'total': 0, 'batches': 435, 'time': 1463.474778175354}
# []
# {'total': 0, 'batches': 436, 'time': 1466.7429151535034}
# []
# {'total': 0, 'batches': 437, 'time': 1470.0668897628784}
# []
# {'total': 0, 'batches': 438, 'time': 1473.3104362487793}
# []
# {'total': 0, 'batches': 439, 'time': 1476.5830681324005}
# []
# {'total': 0, 'batches': 440, 'time': 1479.8555796146393}
# []
# {'total': 0, 'batches': 441, 'time': 1483.4021925926208}
# []
# {'total': 0, 'batches': 442, 'time': 1486.7889320850372}
# []
# {'total': 0, 'batches': 443, 'time': 1490.0491924285889}
# []
# {'total': 0, 'batches': 444, 'time': 1493.3037283420563}
# []
# {'total': 0, 'batches': 445, 'time': 1496.6343994140625}
# []
# {'total': 0, 'batches': 446, 'time': 1499.886059999466}
# []
# {'total': 0, 'batches': 447, 'time': 1503.1484549045563}
# []
# {'total': 0, 'batches': 448, 'time': 1506.4445996284485}
# []
# {'total': 0, 'batches': 449, 'time': 1509.6685948371887}
# []
# {'total': 0, 'batches': 450, 'time': 1512.9455471038818}
# []
# {'total': 0, 'batches': 451, 'time': 1516.3062381744385}
# []
# {'total': 0, 'batches': 452, 'time': 1519.6065077781677}
# []
# {'total': 0, 'batches': 453, 'time': 1522.8595774173737}
# []
# {'total': 0, 'batches': 454, 'time': 1526.0952706336975}
# []
# {'total': 0, 'batches': 455, 'time': 1529.3777523040771}
# []
# {'total': 0, 'batches': 456, 'time': 1532.6635112762451}
# []
# {'total': 0, 'batches': 457, 'time': 1535.9622521400452}
# []
# {'total': 0, 'batches': 458, 'time': 1539.257022857666}
# []
# {'total': 0, 'batches': 459, 'time': 1542.5072841644287}
# []
# {'total': 0, 'batches': 460, 'time': 1545.8060822486877}
# []
# {'total': 0, 'batches': 461, 'time': 1549.1018242835999}
# []
# {'total': 0, 'batches': 462, 'time': 1552.462569952011}
# []
# {'total': 0, 'batches': 463, 'time': 1555.757526397705}
# []
# {'total': 0, 'batches': 464, 'time': 1559.1090149879456}
# []
# {'total': 0, 'batches': 465, 'time': 1562.5123987197876}
# []
# {'total': 0, 'batches': 466, 'time': 1565.732697725296}
# []
# {'total': 0, 'batches': 467, 'time': 1569.0122873783112}
# []
# {'total': 0, 'batches': 468, 'time': 1572.337063074112}
# []
# {'total': 0, 'batches': 469, 'time': 1575.6611297130585}
# []
# {'total': 0, 'batches': 470, 'time': 1578.9848086833954}
# []
# {'total': 0, 'batches': 471, 'time': 1582.2647519111633}
# []
# {'total': 0, 'batches': 472, 'time': 1585.5429604053497}
# []
# {'total': 0, 'batches': 473, 'time': 1588.8628602027893}
# []
# {'total': 0, 'batches': 474, 'time': 1592.1556696891785}
# []
# {'total': 0, 'batches': 475, 'time': 1595.4996802806854}
# []
# {'total': 0, 'batches': 476, 'time': 1598.7777314186096}
# []
# {'total': 0, 'batches': 477, 'time': 1602.0791957378387}
# []
# {'total': 0, 'batches': 478, 'time': 1605.4217143058777}
# []
# {'total': 0, 'batches': 479, 'time': 1608.702115058899}
# []
# {'total': 0, 'batches': 480, 'time': 1612.0260038375854}
# []
# {'total': 0, 'batches': 481, 'time': 1615.2965185642242}
# []
# {'total': 0, 'batches': 482, 'time': 1618.5843567848206}
# []
# {'total': 0, 'batches': 483, 'time': 1621.8794798851013}
# []
# {'total': 0, 'batches': 484, 'time': 1625.228877544403}
# []
# {'total': 0, 'batches': 485, 'time': 1628.5035998821259}
# []
# {'total': 0, 'batches': 486, 'time': 1631.768051624298}
# []
# {'total': 0, 'batches': 487, 'time': 1635.0130984783173}
# []
# {'total': 0, 'batches': 488, 'time': 1638.2439982891083}
# []
# {'total': 0, 'batches': 489, 'time': 1641.536690711975}
# []
# {'total': 0, 'batches': 490, 'time': 1644.8374090194702}
# []
# {'total': 0, 'batches': 491, 'time': 1648.136752128601}
# []
# {'total': 0, 'batches': 492, 'time': 1651.3731610774994}
# []
# {'total': 0, 'batches': 493, 'time': 1654.6513793468475}
# []
# {'total': 0, 'batches': 494, 'time': 1657.8987848758698}
# []
# {'total': 0, 'batches': 495, 'time': 1661.2014088630676}
# []
# {'total': 0, 'batches': 496, 'time': 1664.4745910167694}
# []
# {'total': 0, 'batches': 497, 'time': 1667.7359631061554}
# []
# {'total': 0, 'batches': 498, 'time': 1671.0792853832245}
# []
# {'total': 0, 'batches': 499, 'time': 1674.3925359249115}
# []
# {'total': 0, 'batches': 500, 'time': 1677.764521598816}
# []
# {'total': 0, 'batches': 501, 'time': 1681.0523052215576}
# []
# {'total': 0, 'batches': 502, 'time': 1684.3614404201508}
# []
# {'total': 0, 'batches': 503, 'time': 1687.6444864273071}
# []
# {'total': 0, 'batches': 504, 'time': 1690.9470310211182}
# []
# {'total': 0, 'batches': 505, 'time': 1694.2699298858643}
# []
# {'total': 0, 'batches': 506, 'time': 1697.6017699241638}
# []
# {'total': 0, 'batches': 507, 'time': 1700.8790245056152}
# []
# {'total': 0, 'batches': 508, 'time': 1704.2323791980743}
# []
# {'total': 0, 'batches': 509, 'time': 1707.4862773418427}
# []
# {'total': 0, 'batches': 510, 'time': 1710.7120413780212}
# []
# {'total': 0, 'batches': 511, 'time': 1714.0469281673431}
# []
# {'total': 0, 'batches': 512, 'time': 1717.4156694412231}
# []
# {'total': 0, 'batches': 513, 'time': 1720.7081136703491}
# []
# {'total': 0, 'batches': 514, 'time': 1723.9976749420166}
# []
# {'total': 0, 'batches': 515, 'time': 1727.2899506092072}
# []
# {'total': 0, 'batches': 516, 'time': 1730.6466929912567}
# []
# {'total': 0, 'batches': 517, 'time': 1733.964587211609}
# []
# {'total': 0, 'batches': 518, 'time': 1737.2738857269287}
# []
# {'total': 0, 'batches': 519, 'time': 1740.5886957645416}
# []
# {'total': 0, 'batches': 520, 'time': 1743.8868615627289}
# []
# {'total': 0, 'batches': 521, 'time': 1747.2521126270294}
# []
# {'total': 0, 'batches': 522, 'time': 1750.558824300766}
# []
# {'total': 0, 'batches': 523, 'time': 1753.8818531036377}
# []
# {'total': 0, 'batches': 524, 'time': 1757.1852960586548}
# []
# {'total': 0, 'batches': 525, 'time': 1760.444972038269}
# []
# {'total': 0, 'batches': 526, 'time': 1763.6983189582825}
# []
# {'total': 0, 'batches': 527, 'time': 1767.0250630378723}
# []
# {'total': 0, 'batches': 528, 'time': 1770.3277230262756}
# []
# {'total': 0, 'batches': 529, 'time': 1773.6945898532867}
# []
# {'total': 0, 'batches': 530, 'time': 1777.04172706604}
# []
# {'total': 0, 'batches': 531, 'time': 1780.3876962661743}
# []
# {'total': 0, 'batches': 532, 'time': 1783.7271285057068}
# []
# {'total': 0, 'batches': 533, 'time': 1787.0222344398499}
# []
# {'total': 0, 'batches': 534, 'time': 1790.2692818641663}
# []
# {'total': 0, 'batches': 535, 'time': 1793.5349941253662}
# []
# {'total': 0, 'batches': 536, 'time': 1796.8344521522522}
# []
# {'total': 0, 'batches': 537, 'time': 1800.1028530597687}
# []
# {'total': 0, 'batches': 538, 'time': 1803.4263100624084}
# []
# {'total': 0, 'batches': 539, 'time': 1806.7262411117554}
# []
# {'total': 0, 'batches': 540, 'time': 1810.005538225174}
# []
# {'total': 0, 'batches': 541, 'time': 1813.3220627307892}
# []
# {'total': 0, 'batches': 542, 'time': 1816.59978890419}
# []
# {'total': 0, 'batches': 543, 'time': 1819.9156308174133}
# []
# {'total': 0, 'batches': 544, 'time': 1823.268658876419}
# []
# {'total': 0, 'batches': 545, 'time': 1826.5802175998688}
# []
# {'total': 0, 'batches': 546, 'time': 1829.8598110675812}
# []
# {'total': 0, 'batches': 547, 'time': 1833.222971200943}
# []
# {'total': 0, 'batches': 548, 'time': 1836.5876488685608}
# []
# {'total': 0, 'batches': 549, 'time': 1839.869960784912}
# []
# {'total': 0, 'batches': 550, 'time': 1843.1021585464478}
# []
# {'total': 0, 'batches': 551, 'time': 1846.4046857357025}
# []
# {'total': 0, 'batches': 552, 'time': 1849.6866762638092}
# []
# {'total': 0, 'batches': 553, 'time': 1852.92888712883}
# []
# {'total': 0, 'batches': 554, 'time': 1856.258044242859}
# []
# {'total': 0, 'batches': 555, 'time': 1859.5239944458008}
# []
# {'total': 0, 'batches': 556, 'time': 1862.8267333507538}
# []
# {'total': 0, 'batches': 557, 'time': 1866.089834690094}
# []
# {'total': 0, 'batches': 558, 'time': 1869.3730504512787}
# []
# {'total': 0, 'batches': 559, 'time': 1872.6888010501862}
# []
# {'total': 0, 'batches': 560, 'time': 1876.0328319072723}
# []
# {'total': 0, 'batches': 561, 'time': 1879.3207771778107}
# []
# {'total': 0, 'batches': 562, 'time': 1882.5867133140564}
# []
# {'total': 0, 'batches': 563, 'time': 1885.9374601840973}
# []
# {'total': 0, 'batches': 564, 'time': 1889.2474393844604}
# []
# {'total': 0, 'batches': 565, 'time': 1892.5833044052124}
# []
# {'total': 0, 'batches': 566, 'time': 1895.9403760433197}
# []
# {'total': 0, 'batches': 567, 'time': 1899.2449991703033}
# []
# {'total': 0, 'batches': 568, 'time': 1902.5159952640533}
# []
# {'total': 0, 'batches': 569, 'time': 1905.812067747116}
# []
# {'total': 0, 'batches': 570, 'time': 1909.174785375595}
# []
# {'total': 0, 'batches': 571, 'time': 1912.5284204483032}
# []
# {'total': 0, 'batches': 572, 'time': 1915.8436486721039}
# []
# {'total': 0, 'batches': 573, 'time': 1919.154294013977}
# []
# {'total': 0, 'batches': 574, 'time': 1922.4415605068207}
# []
# {'total': 0, 'batches': 575, 'time': 1925.7585752010345}
# []
# {'total': 0, 'batches': 576, 'time': 1929.0672676563263}
# []
# {'total': 0, 'batches': 577, 'time': 1932.3567805290222}
# []
# {'total': 0, 'batches': 578, 'time': 1935.6371321678162}
# []
# {'total': 0, 'batches': 579, 'time': 1938.9018931388855}
# []
# {'total': 0, 'batches': 580, 'time': 1942.2065234184265}
# []
# {'total': 0, 'batches': 581, 'time': 1945.5827174186707}
# []
# {'total': 0, 'batches': 582, 'time': 1948.8576924800873}
# []
# {'total': 0, 'batches': 583, 'time': 1952.1419744491577}
# []
# {'total': 0, 'batches': 584, 'time': 1955.4178359508514}
# []
# {'total': 0, 'batches': 585, 'time': 1958.7336008548737}
# []
# {'total': 0, 'batches': 586, 'time': 1962.0567486286163}
# []
# {'total': 0, 'batches': 587, 'time': 1965.3614823818207}
# []
# {'total': 0, 'batches': 588, 'time': 1968.6612975597382}
# []
# {'total': 0, 'batches': 589, 'time': 1972.0278215408325}
# []
# {'total': 0, 'batches': 590, 'time': 1975.343453168869}
# []
# {'total': 0, 'batches': 591, 'time': 1978.6803078651428}
# []
# {'total': 0, 'batches': 592, 'time': 1981.9808189868927}
# []
# {'total': 0, 'batches': 593, 'time': 1985.2543499469757}
# []
# {'total': 0, 'batches': 594, 'time': 1988.564593553543}
# []
# {'total': 0, 'batches': 595, 'time': 1991.8493056297302}
# []
# {'total': 0, 'batches': 596, 'time': 1995.1379566192627}
# []
# {'total': 0, 'batches': 597, 'time': 1998.4553740024567}
# []
# {'total': 0, 'batches': 598, 'time': 2001.748296737671}
# []
# {'total': 0, 'batches': 599, 'time': 2005.0943846702576}
# []
# {'total': 0, 'batches': 600, 'time': 2008.4317390918732}
# []
# {'total': 0, 'batches': 601, 'time': 2011.7695178985596}
# []
# {'total': 0, 'batches': 602, 'time': 2015.0740983486176}
# []
# {'total': 0, 'batches': 603, 'time': 2018.3593518733978}
# []
# {'total': 0, 'batches': 604, 'time': 2021.6784641742706}
# []
# {'total': 0, 'batches': 605, 'time': 2025.0219142436981}
# []
# {'total': 0, 'batches': 606, 'time': 2028.346437215805}
# []
# {'total': 0, 'batches': 607, 'time': 2031.6929697990417}
# []
# {'total': 0, 'batches': 608, 'time': 2035.0195252895355}
# []
# {'total': 0, 'batches': 609, 'time': 2038.3418962955475}
# []
# {'total': 0, 'batches': 610, 'time': 2041.676153421402}
# []
# {'total': 0, 'batches': 611, 'time': 2044.9843592643738}
# []
# {'total': 0, 'batches': 612, 'time': 2048.312656879425}
# []
# {'total': 0, 'batches': 613, 'time': 2051.6068856716156}
# []
# {'total': 0, 'batches': 614, 'time': 2054.942129135132}
# []
# {'total': 0, 'batches': 615, 'time': 2058.272372484207}
# []
# {'total': 0, 'batches': 616, 'time': 2061.581978559494}
# []
# {'total': 0, 'batches': 617, 'time': 2064.843417406082}
# []
# {'total': 0, 'batches': 618, 'time': 2068.158193588257}
# []
# {'total': 0, 'batches': 619, 'time': 2071.4673190116882}
# []
# {'total': 0, 'batches': 620, 'time': 2074.782406806946}
# []
# {'total': 0, 'batches': 621, 'time': 2078.133954524994}
# []
# {'total': 0, 'batches': 622, 'time': 2081.4432282447815}
# []
# {'total': 0, 'batches': 623, 'time': 2084.792288541794}
# []
# {'total': 0, 'batches': 624, 'time': 2088.1764760017395}
# []
# {'total': 0, 'batches': 625, 'time': 2091.532000541687}
# []
# {'total': 0, 'batches': 626, 'time': 2094.8557481765747}
# []
# {'total': 0, 'batches': 627, 'time': 2098.212388277054}
# []
# {'total': 0, 'batches': 628, 'time': 2101.49441075325}
# []
# {'total': 0, 'batches': 629, 'time': 2104.834448814392}
# []
# {'total': 0, 'batches': 630, 'time': 2108.1210758686066}
# []
# {'total': 0, 'batches': 631, 'time': 2111.38440656662}
# []
# {'total': 0, 'batches': 632, 'time': 2114.7860448360443}
# []
# {'total': 0, 'batches': 633, 'time': 2118.0846869945526}
# []
# {'total': 0, 'batches': 634, 'time': 2121.4298753738403}
# []
# {'total': 0, 'batches': 635, 'time': 2124.7824971675873}
# []
# {'total': 0, 'batches': 636, 'time': 2128.077323436737}
# []
# {'total': 0, 'batches': 637, 'time': 2131.379597902298}
# []
# {'total': 0, 'batches': 638, 'time': 2134.7302939891815}
# []
# {'total': 0, 'batches': 639, 'time': 2138.0168318748474}
# []
# {'total': 0, 'batches': 640, 'time': 2141.3856880664825}
# []
# {'total': 0, 'batches': 641, 'time': 2144.7424335479736}
# []
# {'total': 0, 'batches': 642, 'time': 2148.026133775711}
# []
# {'total': 0, 'batches': 643, 'time': 2151.367511987686}
# []
# {'total': 0, 'batches': 644, 'time': 2154.6786663532257}
# []
# {'total': 0, 'batches': 645, 'time': 2157.9995481967926}
# []
# {'total': 0, 'batches': 646, 'time': 2161.348011493683}
# []
# {'total': 0, 'batches': 647, 'time': 2164.6478219032288}
# []
# {'total': 0, 'batches': 648, 'time': 2167.945746421814}
# []
# {'total': 0, 'batches': 649, 'time': 2171.2341752052307}
# []
# {'total': 0, 'batches': 650, 'time': 2174.53871011734}
# []
# {'total': 0, 'batches': 651, 'time': 2177.8964779376984}
# []
# {'total': 0, 'batches': 652, 'time': 2181.189541578293}
# []
# {'total': 0, 'batches': 653, 'time': 2184.4923045635223}
# []
# {'total': 0, 'batches': 654, 'time': 2187.7787642478943}
# []
# {'total': 0, 'batches': 655, 'time': 2191.069546699524}
# []
# {'total': 0, 'batches': 656, 'time': 2194.6180489063263}
# []
# {'total': 0, 'batches': 657, 'time': 2198.0778679847717}
# []
# {'total': 0, 'batches': 658, 'time': 2201.3729219436646}
# []
# {'total': 0, 'batches': 659, 'time': 2204.72283911705}
# []
# {'total': 0, 'batches': 660, 'time': 2208.020302295685}
# []
# {'total': 0, 'batches': 661, 'time': 2211.402895450592}
# []
# {'total': 0, 'batches': 662, 'time': 2214.720896244049}
# []
# {'total': 0, 'batches': 663, 'time': 2218.011265516281}
# []
# {'total': 0, 'batches': 664, 'time': 2221.3142166137695}
# []
# {'total': 0, 'batches': 665, 'time': 2224.629831314087}
# []
# {'total': 0, 'batches': 666, 'time': 2228.077731370926}
# []
# {'total': 0, 'batches': 667, 'time': 2231.3712458610535}
# []
# {'total': 0, 'batches': 668, 'time': 2234.716945171356}
# []
# {'total': 0, 'batches': 669, 'time': 2238.049420118332}
# []
# {'total': 0, 'batches': 670, 'time': 2241.4315831661224}
# []
# {'total': 0, 'batches': 671, 'time': 2244.79008936882}
# []
# {'total': 0, 'batches': 672, 'time': 2248.0715007781982}
# []
# {'total': 0, 'batches': 673, 'time': 2251.3814747333527}
# []
# {'total': 0, 'batches': 674, 'time': 2254.6784036159515}
# []
# {'total': 0, 'batches': 675, 'time': 2257.99102640152}
# []
# {'total': 0, 'batches': 676, 'time': 2261.3264775276184}
# []
# {'total': 0, 'batches': 677, 'time': 2264.6220409870148}
# []
# {'total': 0, 'batches': 678, 'time': 2267.8798458576202}
# []
# {'total': 0, 'batches': 679, 'time': 2271.1680796146393}
# []
# {'total': 0, 'batches': 680, 'time': 2274.4541251659393}
# []
# {'total': 0, 'batches': 681, 'time': 2277.855457544327}
# []
# {'total': 0, 'batches': 682, 'time': 2281.140820980072}
# []
# {'total': 0, 'batches': 683, 'time': 2284.4494726657867}
# []
# {'total': 0, 'batches': 684, 'time': 2287.7087337970734}
# []
# {'total': 0, 'batches': 685, 'time': 2291.0512664318085}
# []
# {'total': 0, 'batches': 686, 'time': 2294.48921084404}
# []
# {'total': 0, 'batches': 687, 'time': 2297.9014678001404}
# []
# {'total': 0, 'batches': 688, 'time': 2301.2743062973022}
# []
# {'total': 0, 'batches': 689, 'time': 2304.6395893096924}
# []
# {'total': 0, 'batches': 690, 'time': 2308.005276441574}
# []
# {'total': 0, 'batches': 691, 'time': 2311.405789375305}
# []
# {'total': 0, 'batches': 692, 'time': 2314.6745126247406}
# []
# {'total': 0, 'batches': 693, 'time': 2318.0257318019867}
# []
# {'total': 0, 'batches': 694, 'time': 2321.2797853946686}
# []
# {'total': 0, 'batches': 695, 'time': 2324.6426434516907}
# []
# {'total': 0, 'batches': 696, 'time': 2328.264815568924}
# []
# {'total': 0, 'batches': 697, 'time': 2331.6321597099304}
# []
# {'total': 0, 'batches': 698, 'time': 2334.952713727951}
# []
# {'total': 0, 'batches': 699, 'time': 2338.243744134903}
# []
# {'total': 0, 'batches': 700, 'time': 2341.5252273082733}
# []
# {'total': 0, 'batches': 701, 'time': 2344.8001432418823}
# []
# {'total': 0, 'batches': 702, 'time': 2348.0797595977783}
# []
# {'total': 0, 'batches': 703, 'time': 2351.3698217868805}
# []
# {'total': 0, 'batches': 704, 'time': 2354.6933443546295}
# []
# {'total': 0, 'batches': 705, 'time': 2357.995025873184}
# []
# {'total': 0, 'batches': 706, 'time': 2361.4391865730286}
# []
# {'total': 0, 'batches': 707, 'time': 2364.714190721512}
# []
# {'total': 0, 'batches': 708, 'time': 2368.0373814105988}
# []
# {'total': 0, 'batches': 709, 'time': 2371.3751714229584}
# []
# {'total': 0, 'batches': 710, 'time': 2374.6977183818817}
# []
# {'total': 0, 'batches': 711, 'time': 2378.0304782390594}
# []
# {'total': 0, 'batches': 712, 'time': 2381.338367700577}
# []
# {'total': 0, 'batches': 713, 'time': 2384.703559398651}
# []
# {'total': 0, 'batches': 714, 'time': 2388.080960035324}
# []
# {'total': 0, 'batches': 715, 'time': 2391.500363111496}
# []
# {'total': 0, 'batches': 716, 'time': 2394.97318649292}
# []
# {'total': 0, 'batches': 717, 'time': 2398.2713239192963}
# []
# {'total': 0, 'batches': 718, 'time': 2401.6088008880615}
# []
# {'total': 0, 'batches': 719, 'time': 2404.9018108844757}
# []
# {'total': 0, 'batches': 720, 'time': 2408.331417322159}
# []
# {'total': 0, 'batches': 721, 'time': 2411.726035118103}
# []
# {'total': 0, 'batches': 722, 'time': 2415.094600915909}
# []
# {'total': 0, 'batches': 723, 'time': 2418.4066603183746}
# []
# {'total': 0, 'batches': 724, 'time': 2421.8510518074036}
# []
# {'total': 0, 'batches': 725, 'time': 2425.2827157974243}
# []
# {'total': 0, 'batches': 726, 'time': 2428.625999212265}
# []
# {'total': 0, 'batches': 727, 'time': 2431.974640607834}
# []
# {'total': 0, 'batches': 728, 'time': 2435.3133931159973}
# []
# {'total': 0, 'batches': 729, 'time': 2438.6305305957794}
# []
# {'total': 0, 'batches': 730, 'time': 2441.9862422943115}
# []
# {'total': 0, 'batches': 731, 'time': 2445.301552295685}
# []
# {'total': 0, 'batches': 732, 'time': 2448.6272389888763}
# []
# {'total': 0, 'batches': 733, 'time': 2452.0041670799255}
# []
# {'total': 0, 'batches': 734, 'time': 2455.486813545227}
# []
# {'total': 0, 'batches': 735, 'time': 2458.8755235671997}
# []
# {'total': 0, 'batches': 736, 'time': 2462.219712972641}
# []
# {'total': 0, 'batches': 737, 'time': 2465.581097841263}
# []
# {'total': 0, 'batches': 738, 'time': 2468.9202842712402}
# []
# {'total': 0, 'batches': 739, 'time': 2472.230527162552}
# []
# {'total': 0, 'batches': 740, 'time': 2475.5654900074005}
# []
# {'total': 0, 'batches': 741, 'time': 2478.897899389267}
# []
# {'total': 0, 'batches': 742, 'time': 2482.2415733337402}
# []
# {'total': 0, 'batches': 743, 'time': 2485.509548664093}
# []
# ...
# []
# {'total': 0, 'batches': 1, 'time': 0.019814252853393555}
# []
# {'total': 0, 'batches': 1, 'time': 0.016297340393066406}
# []
# {'total': 0, 'batches': 1, 'time': 0.0566103458404541}
# []
# {'total': 0, 'batches': 1, 'time': 0.026850223541259766}
# []
# {'total': 0, 'batches': 1, 'time': 0.019696950912475586}
# []
# {'total': 0, 'batches': 1, 'time': 0.019000530242919922}
# []
# {'total': 0, 'batches': 1, 'time': 0.02046036720275879}
# []
# {'total': 0, 'batches': 1, 'time': 0.021298885345458984}
# []
# {'total': 0, 'batches': 1, 'time': 0.01874709129333496}
# []
# {'total': 0, 'batches': 1, 'time': 0.04677748680114746}
# []
# {'total': 0, 'batches': 1, 'time': 0.026471853256225586}
# []
# {'total': 0, 'batches': 1, 'time': 0.023192882537841797}
# []
# {'total': 0, 'batches': 1, 'time': 3.6437761783599854}
# []
# {'total': 0, 'batches': 2, 'time': 7.241863489151001}
# []
# {'total': 0, 'batches': 3, 'time': 10.413742542266846}
# []
# {'total': 0, 'batches': 1, 'time': 0.19840025901794434}
# []
# {'total': 0, 'batches': 1, 'time': 0.017523765563964844}
# []
# {'total': 0, 'batches': 1, 'time': 0.017924070358276367}
# []
# {'total': 0, 'batches': 1, 'time': 0.01864933967590332}
# []
# {'total': 0, 'batches': 1, 'time': 0.24782299995422363}
# []
# {'total': 0, 'batches': 1, 'time': 0.024578094482421875}
# []
# {'total': 0, 'batches': 1, 'time': 0.022624492645263672}
# []
# {'total': 0, 'batches': 1, 'time': 0.01682877540588379}
# []
# {'total': 0, 'batches': 1, 'time': 0.02007579803466797}
# []
# {'total': 0, 'batches': 1, 'time': 0.03040933609008789}
# []
# {'total': 0, 'batches': 1, 'time': 3.585533857345581}
# []
# {'total': 0, 'batches': 2, 'time': 3.900848865509033}
# []
# {'total': 0, 'batches': 1, 'time': 0.019744873046875}
# []
# {'total': 0, 'batches': 1, 'time': 0.01629471778869629}
# []
# {'total': 0, 'batches': 1, 'time': 0.018973112106323242}
# []
# {'total': 0, 'batches': 1, 'time': 0.025185585021972656}
# []
# {'total': 0, 'batches': 1, 'time': 0.02799367904663086}
# []
# {'total': 0, 'batches': 1, 'time': 0.01662755012512207}
# []
# {'total': 0, 'batches': 1, 'time': 0.01839160919189453}
# []
# {'total': 0, 'batches': 1, 'time': 0.0160062313079834}
# []
# {'total': 0, 'batches': 1, 'time': 0.022226572036743164}
# []
# {'total': 0, 'batches': 1, 'time': 0.02409505844116211}
# []
# {'total': 0, 'batches': 1, 'time': 0.017119407653808594}
# []
# {'total': 0, 'batches': 1, 'time': 0.0244901180267334}
# []
# {'total': 0, 'batches': 1, 'time': 0.017835378646850586}
# []
# {'total': 0, 'batches': 1, 'time': 0.017121076583862305}
# []
# {'total': 0, 'batches': 1, 'time': 0.019597291946411133}
# []
# {'total': 0, 'batches': 1, 'time': 0.02208709716796875}
# []
# {'total': 0, 'batches': 1, 'time': 0.03515481948852539}
# []
# {'total': 0, 'batches': 1, 'time': 0.018984317779541016}
# []
# {'total': 0, 'batches': 1, 'time': 0.018668174743652344}
# []
# {'total': 0, 'batches': 1, 'time': 0.020125150680541992}
# []
# {'total': 0, 'batches': 1, 'time': 0.0182650089263916}
# []
# {'total': 0, 'batches': 1, 'time': 0.0181272029876709}
# []
# {'total': 0, 'batches': 1, 'time': 0.026491165161132812}
# []
# {'total': 0, 'batches': 1, 'time': 0.02019643783569336}
# []
# {'total': 0, 'batches': 1, 'time': 0.017706632614135742}
# []
# {'total': 0, 'batches': 1, 'time': 0.05443000793457031}
# []
# {'total': 0, 'batches': 1, 'time': 0.02033257484436035}
# []
# {'total': 0, 'batches': 1, 'time': 0.02657794952392578}
# []
# {'total': 0, 'batches': 1, 'time': 0.01832866668701172}
# []
# {'total': 0, 'batches': 1, 'time': 0.018417835235595703}
# []
# {'total': 0, 'batches': 1, 'time': 0.020502567291259766}
# []
# {'total': 0, 'batches': 1, 'time': 0.025307416915893555}
# []
# {'total': 0, 'batches': 1, 'time': 0.016155242919921875}
# []
# {'total': 0, 'batches': 1, 'time': 0.018537521362304688}
# []
# {'total': 0, 'batches': 1, 'time': 3.2906956672668457}
# []
# {'total': 0, 'batches': 2, 'time': 6.421599864959717}
# []
# {'total': 0, 'batches': 3, 'time': 9.670285701751709}
# []
# {'total': 0, 'batches': 4, 'time': 12.95671534538269}
# []
# {'total': 0, 'batches': 5, 'time': 16.21383810043335}
# []
# {'total': 0, 'batches': 6, 'time': 19.47130060195923}
# []
# {'total': 0, 'batches': 7, 'time': 21.251341819763184}
# []
# {'total': 0, 'batches': 1, 'time': 0.01726698875427246}
# []
# {'total': 0, 'batches': 1, 'time': 0.040349721908569336}
# []
# {'total': 0, 'batches': 1, 'time': 0.0208892822265625}
# []
# {'total': 0, 'batches': 1, 'time': 0.0234222412109375}
# []
# {'total': 0, 'batches': 1, 'time': 0.019812345504760742}
# []
# {'total': 0, 'batches': 1, 'time': 0.03083491325378418}
# []
# {'total': 0, 'batches': 1, 'time': 0.02484893798828125}
# []
# {'total': 0, 'batches': 1, 'time': 0.02166891098022461}
# []
# {'total': 0, 'batches': 1, 'time': 0.02335643768310547}
# []
# {'total': 0, 'batches': 1, 'time': 0.02385711669921875}
# []
# {'total': 0, 'batches': 1, 'time': 0.1188955307006836}
# []
# {'total': 0, 'batches': 1, 'time': 0.016417741775512695}
# []
# {'total': 0, 'batches': 1, 'time': 0.018184900283813477}
# []
# {'total': 0, 'batches': 1, 'time': 0.01663351058959961}
# []
# {'total': 0, 'batches': 1, 'time': 0.022307634353637695}
# []
# {'total': 0, 'batches': 1, 'time': 0.021249771118164062}
# []
# {'total': 0, 'batches': 1, 'time': 0.095489501953125}
# []
# {'total': 0, 'batches': 1, 'time': 0.019346952438354492}
# []
# {'total': 0, 'batches': 1, 'time': 0.020703554153442383}
# []
# {'total': 0, 'batches': 1, 'time': 0.01779961585998535}
# []
# {'total': 0, 'batches': 1, 'time': 0.01592087745666504}
# []
# {'total': 0, 'batches': 1, 'time': 0.015575647354125977}
# []
# {'total': 0, 'batches': 1, 'time': 0.02499699592590332}
# []
# {'total': 0, 'batches': 1, 'time': 0.018059492111206055}
# []
# {'total': 0, 'batches': 1, 'time': 0.018043041229248047}
# []
# {'total': 0, 'batches': 1, 'time': 0.016535282135009766}
# []
# {'total': 0, 'batches': 1, 'time': 0.018097400665283203}
# []
# {'total': 0, 'batches': 1, 'time': 0.015881776809692383}
# []
# {'total': 0, 'batches': 1, 'time': 0.03412294387817383}
# []
# {'total': 0, 'batches': 1, 'time': 0.017730712890625}
# []
# {'total': 0, 'batches': 1, 'time': 0.018555402755737305}
# []
# {'total': 0, 'batches': 1, 'time': 0.019520282745361328}
# []
# {'total': 0, 'batches': 1, 'time': 0.01922917366027832}
# []
# {'total': 0, 'batches': 1, 'time': 0.03298759460449219}
# []
# {'total': 0, 'batches': 1, 'time': 0.018862485885620117}
# []
# {'total': 0, 'batches': 1, 'time': 0.018523216247558594}
# []
# {'total': 0, 'batches': 1, 'time': 0.024080514907836914}
# []
# {'total': 0, 'batches': 1, 'time': 0.016095399856567383}
# []
# {'total': 0, 'batches': 1, 'time': 0.018044710159301758}
# []
# {'total': 0, 'batches': 1, 'time': 0.018497228622436523}
# []
# {'total': 0, 'batches': 1, 'time': 0.020071983337402344}
# []
# {'total': 0, 'batches': 1, 'time': 0.018709182739257812}
# []
# {'total': 0, 'batches': 1, 'time': 0.056554555892944336}
# []
# {'total': 0, 'batches': 1, 'time': 0.03253984451293945}
# []
# {'total': 0, 'batches': 1, 'time': 0.01640629768371582}
# []
# {'total': 0, 'batches': 1, 'time': 0.019727706909179688}
# []
# {'total': 0, 'batches': 1, 'time': 0.02092742919921875}
# []
# {'total': 0, 'batches': 1, 'time': 1.439528226852417}
# []
# {'total': 0, 'batches': 1, 'time': 3.6026575565338135}
# []
# {'total': 0, 'batches': 2, 'time': 5.745835065841675}
# []
# {'total': 0, 'batches': 1, 'time': 0.03352952003479004}
# []
# {'total': 0, 'batches': 1, 'time': 2.6786117553710938}
# []
# {'total': 0, 'batches': 1, 'time': 0.018471240997314453}
# []
# {'total': 0, 'batches': 1, 'time': 0.02363729476928711}
# []
# {'total': 0, 'batches': 1, 'time': 0.026096582412719727}
# []
# {'total': 0, 'batches': 1, 'time': 0.01638960838317871}
# []
# {'total': 0, 'batches': 1, 'time': 0.017498493194580078}
# []
# {'total': 0, 'batches': 1, 'time': 0.03806495666503906}
# []
# {'total': 0, 'batches': 1, 'time': 0.03375983238220215}
# []
# {'total': 0, 'batches': 1, 'time': 0.023221731185913086}
# []
# {'total': 0, 'batches': 1, 'time': 0.025981426239013672}
# []
# {'total': 0, 'batches': 1, 'time': 3.5444376468658447}
# []
# {'total': 0, 'batches': 2, 'time': 7.0458903312683105}
# []
# {'total': 0, 'batches': 3, 'time': 10.525367021560669}
# []
# {'total': 0, 'batches': 4, 'time': 12.144817113876343}
# []
# {'total': 0, 'batches': 1, 'time': 3.3761699199676514}
# []
# {'total': 0, 'batches': 2, 'time': 6.859846830368042}
# []
# {'total': 0, 'batches': 3, 'time': 10.27461051940918}
# []
# {'total': 0, 'batches': 4, 'time': 13.719692945480347}
# []
# {'total': 0, 'batches': 5, 'time': 17.1747043132782}
# []
# {'total': 0, 'batches': 6, 'time': 20.743327856063843}
# []
# {'total': 0, 'batches': 7, 'time': 23.466336727142334}
# []
# {'total': 0, 'batches': 1, 'time': 0.027978181838989258}
# []
# {'total': 0, 'batches': 1, 'time': 0.018697261810302734}
# []
# {'total': 0, 'batches': 1, 'time': 0.026105165481567383}
# []
# {'total': 0, 'batches': 1, 'time': 0.018687009811401367}
# []
# {'total': 0, 'batches': 1, 'time': 0.016308069229125977}
# []
# {'total': 0, 'batches': 1, 'time': 0.01835155487060547}
# []
# {'total': 0, 'batches': 1, 'time': 0.025693178176879883}
# []
# {'total': 0, 'batches': 1, 'time': 0.018247365951538086}
# []
# {'total': 0, 'batches': 1, 'time': 0.06459951400756836}
# []
# {'total': 0, 'batches': 1, 'time': 0.02016901969909668}
# []
# {'total': 0, 'batches': 1, 'time': 0.018931150436401367}
# []
# {'total': 0, 'batches': 1, 'time': 0.01778268814086914}
# []
# {'total': 0, 'batches': 1, 'time': 0.01564621925354004}
# []
# {'total': 0, 'batches': 1, 'time': 0.016169071197509766}
# []
# {'total': 0, 'batches': 1, 'time': 0.01802372932434082}
# []
# {'total': 0, 'batches': 1, 'time': 0.016184329986572266}
# []
# {'total': 0, 'batches': 1, 'time': 0.01857471466064453}
# []
# {'total': 0, 'batches': 1, 'time': 0.018021345138549805}
# []
# {'total': 0, 'batches': 1, 'time': 0.01804947853088379}
# []
# {'total': 0, 'batches': 1, 'time': 0.02534174919128418}
# []
# {'total': 0, 'batches': 1, 'time': 0.020288467407226562}
# []
# {'total': 0, 'batches': 1, 'time': 0.04179978370666504}
# []
# {'total': 0, 'batches': 1, 'time': 0.01579117774963379}
# []
# {'total': 0, 'batches': 1, 'time': 0.01594257354736328}
# []
# {'total': 0, 'batches': 1, 'time': 0.019675254821777344}
# []
# {'total': 0, 'batches': 1, 'time': 0.018363475799560547}
# []
# {'total': 0, 'batches': 1, 'time': 0.018590450286865234}
# []
# {'total': 0, 'batches': 1, 'time': 0.037760257720947266}
# []
# {'total': 0, 'batches': 1, 'time': 0.019453763961791992}
# []
# {'total': 0, 'batches': 1, 'time': 0.16005539894104004}
# []
# {'total': 0, 'batches': 1, 'time': 0.01976776123046875}
# []
# {'total': 0, 'batches': 1, 'time': 0.016266822814941406}
# []
# {'total': 0, 'batches': 1, 'time': 0.017922401428222656}
# []
# {'total': 0, 'batches': 1, 'time': 0.016005754470825195}
# []
# {'total': 0, 'batches': 1, 'time': 0.023195266723632812}
# []
# {'total': 0, 'batches': 1, 'time': 0.018734455108642578}
# []
# {'total': 0, 'batches': 1, 'time': 0.02044367790222168}
# []
# {'total': 0, 'batches': 1, 'time': 0.017718076705932617}
# []
# {'total': 0, 'batches': 1, 'time': 0.016112804412841797}
# []
# {'total': 0, 'batches': 1, 'time': 0.020240068435668945}
# []
# {'total': 0, 'batches': 1, 'time': 0.015819311141967773}
# []
# {'total': 0, 'batches': 1, 'time': 0.01760101318359375}
# []
# {'total': 0, 'batches': 1, 'time': 0.01624441146850586}
# []
# {'total': 0, 'batches': 1, 'time': 0.017859458923339844}
# []
# {'total': 0, 'batches': 1, 'time': 0.018657684326171875}
# []
# {'total': 0, 'batches': 1, 'time': 0.02329874038696289}
# []
# {'total': 0, 'batches': 1, 'time': 0.018414020538330078}
# []
# {'total': 0, 'batches': 1, 'time': 0.021472930908203125}
# []
# {'total': 0, 'batches': 1, 'time': 0.02628016471862793}
# []
# {'total': 0, 'batches': 1, 'time': 0.02381753921508789}
# []
# {'total': 0, 'batches': 1, 'time': 0.027680397033691406}
# []
# {'total': 0, 'batches': 1, 'time': 0.16387271881103516}
# []
# {'total': 0, 'batches': 1, 'time': 0.03878426551818848}
# []
# {'total': 0, 'batches': 1, 'time': 0.02517223358154297}
# []
# {'total': 0, 'batches': 1, 'time': 0.0848996639251709}
# []
# {'total': 0, 'batches': 1, 'time': 0.06911230087280273}
# []
# {'total': 0, 'batches': 1, 'time': 0.019932270050048828}
# []
# {'total': 0, 'batches': 1, 'time': 0.018131256103515625}
# []
# {'total': 0, 'batches': 1, 'time': 0.01948404312133789}
# []
# {'total': 0, 'batches': 1, 'time': 0.02006697654724121}
# []
# {'total': 0, 'batches': 1, 'time': 0.015970230102539062}
# []
# {'total': 0, 'batches': 1, 'time': 0.02048015594482422}
# []
# {'total': 0, 'batches': 1, 'time': 0.02156996726989746}
# []
# {'total': 0, 'batches': 1, 'time': 0.015738964080810547}
# []
# {'total': 0, 'batches': 1, 'time': 0.018130064010620117}
# []
# {'total': 0, 'batches': 1, 'time': 0.015797853469848633}
# []
# {'total': 0, 'batches': 1, 'time': 0.01607060432434082}
# []
# {'total': 0, 'batches': 1, 'time': 2.5699009895324707}
# []
# {'total': 0, 'batches': 1, 'time': 0.017975330352783203}
# []
# {'total': 0, 'batches': 1, 'time': 0.023266077041625977}
# []
# {'total': 0, 'batches': 1, 'time': 0.01643824577331543}
# []
# {'total': 0, 'batches': 1, 'time': 0.01745915412902832}
# []
# {'total': 0, 'batches': 1, 'time': 0.016204833984375}
# []
# {'total': 0, 'batches': 1, 'time': 0.01721811294555664}
# []
# {'total': 0, 'batches': 1, 'time': 0.0785379409790039}
# []
# {'total': 0, 'batches': 1, 'time': 0.020652055740356445}
# []
# {'total': 0, 'batches': 1, 'time': 1.1776444911956787}
# []
# {'total': 0, 'batches': 1, 'time': 0.016124248504638672}
# []
# {'total': 0, 'batches': 1, 'time': 0.018363237380981445}
# []
# {'total': 0, 'batches': 1, 'time': 0.022020816802978516}
# []
# {'total': 0, 'batches': 1, 'time': 0.015814781188964844}
# []
# {'total': 0, 'batches': 1, 'time': 0.02076268196105957}
# []
# {'total': 0, 'batches': 1, 'time': 0.020870447158813477}
# []
# {'total': 0, 'batches': 1, 'time': 0.0171358585357666}
# []
# {'total': 0, 'batches': 1, 'time': 0.01783299446105957}
# []
# {'total': 0, 'batches': 1, 'time': 0.3854103088378906}
# []
# {'total': 0, 'batches': 1, 'time': 0.018659591674804688}
# []
# {'total': 0, 'batches': 1, 'time': 0.015796899795532227}
# []
# {'total': 0, 'batches': 1, 'time': 0.015933513641357422}
# []
# {'total': 0, 'batches': 1, 'time': 0.018396615982055664}
# []
# {'total': 0, 'batches': 1, 'time': 0.017008066177368164}
# []
# {'total': 0, 'batches': 1, 'time': 0.02788400650024414}
# []
# {'total': 0, 'batches': 1, 'time': 0.052780866622924805}
# []
# {'total': 0, 'batches': 1, 'time': 0.016328096389770508}
# []
# {'total': 0, 'batches': 1, 'time': 0.017661571502685547}
# []
# {'total': 0, 'batches': 1, 'time': 0.05473136901855469}
# []
# {'total': 0, 'batches': 1, 'time': 0.10780739784240723}
# []
# {'total': 0, 'batches': 1, 'time': 0.016029834747314453}
# []
# {'total': 0, 'batches': 1, 'time': 0.01632094383239746}
# []
# {'total': 0, 'batches': 1, 'time': 0.015564680099487305}
# []
# {'total': 0, 'batches': 1, 'time': 0.018440961837768555}
# []
# {'total': 0, 'batches': 1, 'time': 0.02794623374938965}
# []
# {'total': 0, 'batches': 1, 'time': 0.01994776725769043}
# []
# {'total': 0, 'batches': 1, 'time': 0.016017913818359375}
# []
# {'total': 0, 'batches': 1, 'time': 0.015987157821655273}
# []
# {'total': 0, 'batches': 1, 'time': 0.018321752548217773}
# []
# {'total': 0, 'batches': 1, 'time': 0.01799750328063965}
# []
# {'total': 0, 'batches': 1, 'time': 0.25112128257751465}
# []
# {'total': 0, 'batches': 1, 'time': 0.01570892333984375}
# []
# {'total': 0, 'batches': 1, 'time': 0.01769852638244629}
# []
# {'total': 0, 'batches': 1, 'time': 0.01653742790222168}
# []
# {'total': 0, 'batches': 1, 'time': 0.01811957359313965}
# []
# {'total': 0, 'batches': 1, 'time': 0.01623988151550293}
# []
# {'total': 0, 'batches': 1, 'time': 0.015760183334350586}
# []
# {'total': 0, 'batches': 1, 'time': 0.01618480682373047}
# []
# {'total': 0, 'batches': 1, 'time': 0.017879724502563477}
# []
# {'total': 0, 'batches': 1, 'time': 0.016112089157104492}
# []
# {'total': 0, 'batches': 1, 'time': 0.015878915786743164}
# []
# {'total': 0, 'batches': 1, 'time': 0.017461776733398438}
# []
# {'total': 0, 'batches': 1, 'time': 0.015732288360595703}
# []
# {'total': 0, 'batches': 1, 'time': 0.016025781631469727}
# []
# {'total': 0, 'batches': 1, 'time': 0.07242941856384277}
# []
# {'total': 0, 'batches': 1, 'time': 0.016567707061767578}
# []
# {'total': 0, 'batches': 1, 'time': 0.015834808349609375}
# []
# {'total': 0, 'batches': 1, 'time': 0.018131732940673828}
# []
# {'total': 0, 'batches': 1, 'time': 0.01871347427368164}
# []
# {'total': 0, 'batches': 1, 'time': 0.018069982528686523}
# []
# {'total': 0, 'batches': 1, 'time': 0.01564955711364746}
# []
# {'total': 0, 'batches': 1, 'time': 0.016019821166992188}
# []
# {'total': 0, 'batches': 1, 'time': 0.016327857971191406}

# %%
src.head()
# Out:
#      node_id
# 0          0
# 36         1
# 135        2
# 269        3
# 278        4

# %%
src.shape
# Out:
# (87110946, 1)

# %%
tar.head()
# Out:
#    node_id
# 0   650146
# 1   650332
# 2   989978
# 3  1054521
# 4  1632931

# %%
tar.shape
# Out:
# (25633917, 1)

# %%
src[~src.isin(tar)].dropna().shape
# Out:
# (87110614, 1)

# %%
node_df_dedup.head()
# Out:
#      node_id
# 0          0
# 36         1
# 135        2
# 269        3
# 278        4

# %%
# %%time

node_dedup_emb = node_df_dedup
node_dedup_emb['embedding'] = node_dedup_emb['node_id'].map(get_embs)
node_dedup_emb.head()

# %%
add_embeddings(node_dedup_emb)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-cdc97f9fc01f> in <module>
# ----> 1 add_embeddings(node_dedup_emb)
#
# NameError: name 'node_dedup_emb' is not defined

# %%
node_dedup_emb.dtypes
# Out:
# node_id       int64
# embedding    object
# dtype: object
